# %%
import pertpy as pt
import scanpy as sc
import pandas as pd
import numpy as np

# %%
adata = pt.dt.dialogue_example()
adata
# Out:
# AnnData object with n_obs × n_vars = 5374 × 6329
#     obs: 'nCount_RNA', 'nFeature_RNA', 'cellQ', 'gender', 'location', 'clinical.status', 'cell.subtypes', 'pathology', 'origin', 'subset'
#     var: 'name'

# %%
#sc.pp.normalize_total(adata, target_sum=1e4)
#sc.pp.log1p(adata)
#sc.pp.scale(adata)
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)

# %%
#adata.obs['Number of counts'] = adata.obs['nCount_RNA']

# %%
dl = pt.tl.Dialogue(sample_id = "clinical.status",
                   celltype_key = "cell.subtypes",
                   n_counts_key = "nCount_RNA",
                   n_mpcs = 3)

# %%
adata, mcps, ws, ct_subs = dl.calculate_multifactor_PMD(
    adata,
    normalize=True,
    solver="lp"
)

# %%
all_results, new_mcps = dl.multilevel_modeling(ct_subs=ct_subs,
                                     mcp_scores=mcps,
                                     ws_dict=ws,
                                     confounder=None,
                                   )
# Out:
# Output()
# 3 MCPs identified for CD8+ IELs and CD8+ IL17+.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 all_results, new_mcps = dl.multilevel_modeling(ct_subs=ct_subs,
#       2                                      mcp_scores=mcps,
#       3                                      ws_dict=ws,
#       4                                      confounder=None,
#       5                                    )
#
# File ~/miniforge3/envs/pertpy5/lib/python3.9/site-packages/pertpy/tools/_dialogue.py:771, in Dialogue.multilevel_modeling(self, ct_subs, mcp_scores, ws_dict, confounder, formula)
#     769 # TODO Check that the genes in result{sig_genes_1] are different and if so note that somewhere and explain why
#     770 result = {}
# --> 771 result["HLM_result_1"], result["sig_genes_1"] = self._apply_HLM_per_MCP_for_one_pair(
#     772     mcp_name=mcp,
#     773     scores_df=mcp_scores_df[cell_type_2],
#     774     ct_data=ct_data_2,
#     775     tme=tme_2,
#     776     sig=sig_1,
#     777     n_counts=self.n_counts_key,
#     778     formula=formula,
#     779     confounder=confounder,
#     780 )
#     781 result["HLM_result_2"], result["sig_genes_2"] = self._apply_HLM_per_MCP_for_one_pair(
#     782     mcp_name=mcp,
#     783     scores_df=mcp_scores_df[cell_type_1],
#    (...)
#     789     confounder=confounder,
#     790 )
#     791 merged_results[mcp] = result
#
# File ~/miniforge3/envs/pertpy5/lib/python3.9/site-packages/pertpy/tools/_dialogue.py:334, in Dialogue._apply_HLM_per_MCP_for_one_pair(self, mcp_name, scores_df, ct_data, tme, sig, n_counts, formula, confounder)
#     304 def _apply_HLM_per_MCP_for_one_pair(  # noqa: N802
#     305     self,
#     306     mcp_name: str,
#    (...)
#     313     confounder: str,
#     314 ) -> tuple[pd.DataFrame, dict[str, Any]]:
#     315     """Applies hierarchical modeling for a single MCP.
#     316
#     317     TODO: separate the sig calculation so that this whole function is more tractable
#    (...)
#     330         The HLM results together with significant up/downregulated genes per MCP
#     331     """
#     332     HLM_result = self._mixed_effects(
#     333         scores=scores_df[[mcp_name]],
# --> 334         x_labels=ct_data.obs[[n_counts, confounder]],
#     335         tme=tme,
#     336         genes_in_mcp=list(sig[mcp_name]["up"]) + list(sig[mcp_name]["down"]),
#     337         formula=formula,
#     338         confounder=confounder,
#     339     )
#     341     HLM_result["up"] = [gene in sig[mcp_name]["up"] for gene in HLM_result.index]
#     343     # extract significant up and downregulated genes
#
# File ~/miniforge3/envs/pertpy5/lib/python3.9/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/miniforge3/envs/pertpy5/lib/python3.9/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/miniforge3/envs/pertpy5/lib/python3.9/site-packages/pandas/core/indexes/base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: '[None] not in index'

# %%
sc.pl.umap(
    adata,
    color=[
        "clinical.status"
    ],
)

# %%
dl = pt.tl.Dialogue(sample_id = "clinical.status",
                   celltype_key = "cell.subtypes",
                   n_counts_key = "nCount_RNA",
                   n_mpcs = 3)

# %%
adata, mcps, ws, ct_subs = dl.calculate_multifactor_PMD(
    adata,
    normalize=True,
    solver="lp"
)

# %%
sc.pl.umap(adata, color=['mcp_0', 'mcp_1', 'clinical.status'], ncols=1, cmap='coolwarm', vcenter=0)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 5374 × 6329
#     obs: 'nCount_RNA', 'nFeature_RNA', 'cellQ', 'gender', 'location', 'clinical.status', 'cell.subtypes', 'pathology', 'origin', 'subset', 'mcp_0', 'mcp_1', 'mcp_2'
#     obsm: 'X_pca', 'X_umap'

# %%
all_results, new_mcps = dl.multilevel_modeling(ct_subs=ct_subs,
                                     mcp_scores=mcps,
                                     ws_dict=ws,
                                     confounder="gender",
                                   )
# Out:
# Output()
# 3 MCPs identified for CD8+ IELs and CD8+ IL17+.
# 3 MCPs identified for CD8+ IELs and CD8+ LP.
# 3 MCPs identified for CD8+ IELs and Macrophages.
# 3 MCPs identified for CD8+ IELs and TA2.
# 3 MCPs identified for CD8+ IL17+ and CD8+ LP.
# 3 MCPs identified for CD8+ IL17+ and Macrophages.
# 3 MCPs identified for CD8+ IL17+ and TA2.
# 3 MCPs identified for CD8+ LP and Macrophages.
# 3 MCPs identified for CD8+ LP and TA2.
# 3 MCPs identified for Macrophages and TA2.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
all_results
# Out:
# {'CD8+ IELs_vs_CD8+ IL17+': {'MCP1': {'HLM_result_1':              estimate         p_val   z_score  p_adjust    up program
#    AAK1        14.948880  6.379106e-07  6.496270  0.000005  True    MCP1
#    ABCE1       13.772942  4.920024e-04  3.609063  0.000725  True    MCP1
#    ABCF1       17.368491  1.262790e-05  5.199699  0.000028  True    MCP1
#    AC020571.3  21.274835  1.377934e-04  4.161801  0.000227  True    MCP1
#    AC092580.4   3.750892  8.006954e-05  4.397563  0.000144  True    MCP1
#    ...               ...           ...       ...       ...   ...     ...
#    YWHAZ        6.972635  7.214107e-05  4.442847  0.000134  True    MCP1
#    YY1         11.032620  1.119959e-04  4.251828  0.000191  True    MCP1
#    ZC3HAV1     13.713115  8.102758e-05  4.392397  0.000145  True    MCP1
#    ZEB2        16.664818  1.060785e-01  1.275402  0.110007  True    MCP1
#    ZNF644      23.374513  5.265439e-07  6.579595  0.000005  True    MCP1
#
#    [252 rows x 6 columns],
#    'sig_genes_1': {'MCP1.up': ['AAK1',
#      'ABCF1',
#      'ACTR2',
#      'ANKRD11',
#      'ANKRD36',
#      'ARAP2',
#      'ARF6',
#      'ARGLU1',
#      'ATM',
#      'ATP5I',
#      'ATP8A1',
#      'BPTF',
#      'C16orf54',
#      'CAPZA1',
#      'CCDC66',
#      'CLEC2B',
#      'COX20',
#      'COX7C',
#      'CREM',
#      'DDX3X',
#      'DNMT1',
#      'EIF3E',
#      'ELF1',
#      'FAM45A',
#      'FYB',
#      'GPRIN3',
#      'HEXIM1',
#      'HIST1H4C',
#      'HNRNPD',
#      'HNRNPH1',
#      'HP1BP3',
#      'IFNG',
#      'ITK',
#      'IWS1',
#      'KLF2',
#      'KLRB1',
#      'KLRD1',
#      'KMT2E',
#      'LNPEP',
#      'MARCH6',
#      'MBNL1',
#      'MCL1',
#      'MDM4',
#      'MGEA5',
#      'MT-ND3',
#      'MT-ND4L',
#      'MT1X',
#      'MTMR9',
#      'MYCBP2',
#      'N4BP2L2',
#      'NCL',
#      'NDUFA3',
#      'NUP50',
#      'OGT',
#      'PAG1',
#      'PHF3',
#      'PIK3R1',
#      'PIP4K2A',
#      'PNPLA8',
#      'POMP',
#      'PPP1CB',
#      'PSD4',
#      'PTP4A2',
#      'PTPRC',
#      'RASGRP1',
#      'RBPJ',
#      'RICTOR',
#      'RNMT',
#      'RORA',
#      'RP11-138A9.1',
#      'RP11-347P5.1',
#      'RP11-349A22.5',
#      'RPL39',
#      'RPS29',
#      'SAMD3',
#      'SEC61G',
#      'SEC62',
#      'SETD5',
#      'SFPQ',
#      'SFXN1',
#      'SHFM1',
#      'SKA2',
#      'SKIL',
#      'SLA',
#      'SLC38A2',
#      'SMARCE1',
#      'SMC1A',
#      'SMCHD1',
#      'SMEK1',
#      'SMG1',
#      'SON',
#      'SRSF5',
#      'SRSF6',
#      'TBC1D2B',
#      'TNRC6B',
#      'TRIM13',
#      'UBA6',
#      'UPF2',
#      'UTRN',
#      'XIST',
#      'ZNF644'],
#     'MCP1.down': ['ALDOA',
#      'ANXA1',
#      'ANXA5',
#      'ARF5',
#      'ARL2',
#      'ARPC2',
#      'ATP5A1',
#      'ATP5G2',
#      'CACYBP',
#      'CAPZB',
#      'CD37',
#      'CD52',
#      'EMP3',
#      'IGHV1OR15-1',
#      'MAD2L2',
#      'MIF',
#      'NBEAL1',
#      'PABPC1',
#      'PKM',
#      'PLP2',
#      'PPP1R11',
#      'PSMD9',
#      'PTGER2',
#      'RAB33A',
#      'RPL10A',
#      'RPL17',
#      'RPS14',
#      'RPS18',
#      'RPSA',
#      'SIRPG',
#      'TECR',
#      'TRAC',
#      'TRGC2',
#      'TSR2',
#      'TUBA1A',
#      'TUBB']},
#    'HLM_result_2':              estimate         p_val    z_score  p_adjust    up program
#    AAK1        15.455581  3.316504e-65  64.780349       NaN  True    MCP1
#    AAMP       -18.428558  6.224674e-84 -83.506913       NaN  True    MCP1
#    ABCE1        9.795581  8.640335e-53  52.364499       NaN  True    MCP1
#    AC009501.4  -7.424977  2.245830e-60 -59.949653       NaN  True    MCP1
#    AC016831.7  11.801609  1.409468e-49  49.151975       NaN  True    MCP1
#    ...               ...           ...        ...       ...   ...     ...
#    ZNF259     -15.419524  7.610269e-15 -14.419630       NaN  True    MCP1
#    ZNF331     -48.723388  2.967691e-80 -79.828611       NaN  True    MCP1
#    ZNF428     -13.657697  9.864975e-29 -28.306934       NaN  True    MCP1
#    ZNF430      27.336075  1.161055e-80  80.236177       NaN  True    MCP1
#    ZRSR2        7.913938  1.990177e-51  51.002138       NaN  True    MCP1
#
#    [446 rows x 6 columns],
#    'sig_genes_2': {'MCP1.up': ['AC092580.4',
#      'ACYP2',
#      'ARFGAP3',
#      'ARHGEF3',
#      'ARL6IP1',
#      'ARPC4',
#      'ASB2',
#      'ATF6B',
#      'ATP5L',
#      'BTG1',
#      'C14orf2',
#      'CARS',
#      'CDKN1B',
#      'CHD1',
#      'CHURC1',
#      'CLEC2B',
#      'CLEC2D',
#      'COA5',
#      'DEK',
#      'DSTN',
#      'FAM65B',
#      'FKBP1A',
#      'FYB',
#      'FYN',
#      'GADD45G',
#      'GANAB',
#      'GPR171',
#      'HADHA',
#      'HAVCR2',
#      'HIC1',
#      'HNRNPA3',
#      'HSH2D',
#      'ILF3',
#      'IP6K2',
#      'KLHDC2',
#      'KLRB1',
#      'LIMD2',
#      'LINS',
#      'LPIN1',
#      'LRRC59',
#      'MRPL33',
#      'MT-ATP6',
#      'MTDH',
#      'MYL12A',
#      'PBRM1',
#      'PCNP',
#      'PPP3CA',
#      'PRPF6',
#      'PSIP1',
#      'PSMD14',
#      'PTPLAD1',
#      'PTPN22',
#      'PTPN7',
#      'RAB27A',
#      'RASGRP1',
#      'RIN3',
#      'RP11-347P5.1',
#      'RP11-349A22.5',
#      'RPL18A',
#      'RPL37',
#      'RPL38',
#      'RPL39',
#      'RPS10',
#      'RPS27',
#      'RPS29',
#      'RPS7',
#      'RTF1',
#      'SDHC',
#      'SEC22B',
#      'SEPT2',
#      'SETD5',
#      'SFXN1',
#      'SHOC2',
#      'SIPA1',
#      'SKA2',
#      'SMARCE1',
#      'SMEK2',
#      'SPNS3',
#      'SRP72',
#      'STK17B',
#      'SUB1',
#      'SYF2',
#      'SYNRG',
#      'TAPBP',
#      'TAX1BP1',
#      'TDG',
#      'TFAM',
#      'TFDP1',
#      'TIMM22',
#      'TMED2',
#      'TMEM2',
#      'TMEM258',
#      'TNRC6B',
#      'TOX',
#      'TPP1',
#      'TRA2B',
#      'TXNDC17',
#      'UQCRB',
#      'USMG5',
#      'VPS25',
#      'ZNF430'],
#     'MCP1.down': ['AAMP',
#      'AC009501.4',
#      'AGA',
#      'AL136419.6',
#      'ANKRD13D',
#      'AP1S1',
#      'ARMCX6',
#      'ATG3',
#      'ATXN10',
#      'ATXN8OS',
#      'B3GNT2',
#      'C16orf91',
#      'C6orf1',
#      'CCDC101',
#      'CCL5',
#      'CD27',
#      'CD48',
#      'CITED2',
#      'CLIC1',
#      'CLK3',
#      'CMC1',
#      'COPS3',
#      'CXCR4',
#      'DCTD',
#      'DHRS7',
#      'DNAJA1',
#      'DUSP2',
#      'EEF1A1',
#      'EIF5A',
#      'ETNK1',
#      'FOSB',
#      'FXYD5',
#      'GAPDH',
#      'GBP1',
#      'HLA-G',
#      'HTATIP2',
#      'INO80C',
#      'ITGB2',
#      'KANSL2',
#      'KIF22',
#      'KLRG1',
#      'KMT2A',
#      'LDHA',
#      'LGALS1',
#      'LYSMD2',
#      'MAN1B1',
#      'METTL17',
#      'MIF',
#      'MPLKIP',
#      'MRPS23',
#      'MSN',
#      'MX1',
#      'NCF1',
#      'NDUFAF3',
#      'NXT1',
#      'PCED1B-AS1',
#      'PIM3',
#      'PLAC8',
#      'PLP2',
#      'PMAIP1',
#      'PPHLN1',
#      'PSMB3',
#      'PSMB9',
#      'PTGER4',
#      'RBM33',
#      'RGCC',
#      'RNF125',
#      'RNF139',
#      'RPL12',
#      'RPL13',
#      'RPL13A',
#      'RPL14',
#      'RPL15',
#      'RPL6',
#      'RPS2',
#      'RPS5',
#      'RPS6',
#      'RPS9',
#      'RSU1',
#      'RWDD1',
#      'S100A10',
#      'S100A11',
#      'SH3GLB1',
#      'SIGIRR',
#      'SLC2A4RG',
#      'SMDT1',
#      'SMG1',
#      'SMPD1',
#      'SMYD2',
#      'SNRNP25',
#      'TAGAP',
#      'TAZ',
#      'TMEM14A',
#      'TMEM199',
#      'TSC22D3',
#      'UBE2B',
#      'VIM',
#      'VPS4A',
#      'XCL1',
#      'ZFP36L2',
#      'ZNF331']}},
#   'MCP2': {'HLM_result_1':              estimate         p_val   z_score  p_adjust     up program
#    AAK1        14.323472  6.727883e-07  6.473152  0.000004   True    MCP2
#    ABCE1       13.220706  4.912975e-04  3.609685  0.000694   True    MCP2
#    ABCF1       16.656729  1.288892e-05  5.190813  0.000027   True    MCP2
#    AC020571.3  20.414993  1.384344e-04  4.159786  0.000217   True    MCP2
#    AC092580.4   3.598777  8.069908e-05  4.394161  0.000136   True    MCP2
#    ...               ...           ...       ...       ...    ...     ...
#    VAMP8       -6.611132  2.947087e-05 -4.831637  0.000055  False    MCP2
#    VIM         -3.847153  7.541662e-04 -3.423563  0.001019  False    MCP2
#    XCL1        -7.832262  5.096274e-07 -6.593777  0.000004  False    MCP2
#    YBX1        -5.482081  1.573381e-03 -3.104196  0.001987  False    MCP2
#    ZFP36       -4.865628  5.220242e-05 -4.583339  0.000093  False    MCP2
#
#    [346 rows x 6 columns],
#    'sig_genes_1': {'MCP2.up': ['AAK1',
#      'ABCF1',
#      'ACTR2',
#      'ANKRD11',
#      'ANKRD36',
#      'ARAP2',
#      'ARF6',
#      'ARGLU1',
#      'ATM',
#      'ATP5I',
#      'ATP8A1',
#      'BPTF',
#      'C16orf54',
#      'CAPZA1',
#      'CCDC66',
#      'CLEC2B',
#      'COX20',
#      'COX7C',
#      'CREM',
#      'DDX3X',
#      'DNMT1',
#      'EIF3E',
#      'ELF1',
#      'FAM45A',
#      'FYB',
#      'GPRIN3',
#      'HEXIM1',
#      'HIST1H4C',
#      'HNRNPD',
#      'HNRNPH1',
#      'HP1BP3',
#      'IFNG',
#      'ITK',
#      'IWS1',
#      'KLF2',
#      'KLRB1',
#      'KLRD1',
#      'KMT2E',
#      'LNPEP',
#      'MARCH6',
#      'MBNL1',
#      'MCL1',
#      'MDM4',
#      'MGEA5',
#      'MT-ND3',
#      'MT-ND4L',
#      'MT1X',
#      'MTMR9',
#      'MYCBP2',
#      'N4BP2L2',
#      'NCL',
#      'NDUFA3',
#      'NUP50',
#      'OGT',
#      'PAG1',
#      'PHF3',
#      'PIK3R1',
#      'PIP4K2A',
#      'PNPLA8',
#      'POMP',
#      'PPP1CB',
#      'PSD4',
#      'PTP4A2',
#      'PTPRC',
#      'RASGRP1',
#      'RBPJ',
#      'RICTOR',
#      'RNMT',
#      'RORA',
#      'RP11-138A9.1',
#      'RP11-347P5.1',
#      'RP11-349A22.5',
#      'RPL39',
#      'RPS29',
#      'SAMD3',
#      'SEC61G',
#      'SEC62',
#      'SETD5',
#      'SFPQ',
#      'SFXN1',
#      'SHFM1',
#      'SKA2',
#      'SKIL',
#      'SLA',
#      'SLC38A2',
#      'SMARCE1',
#      'SMC1A',
#      'SMCHD1',
#      'SMEK1',
#      'SMG1',
#      'SON',
#      'SRSF5',
#      'SRSF6',
#      'TBC1D2B',
#      'TNRC6B',
#      'TRIM13',
#      'UBA6',
#      'UPF2',
#      'UTRN',
#      'XIST',
#      'ZNF644'],
#     'MCP2.down': ['AC009501.4',
#      'ACTB',
#      'ALDOA',
#      'ANXA1',
#      'ANXA5',
#      'ARF5',
#      'ARHGDIB',
#      'ARL2',
#      'ARPC1B',
#      'ATP5A1',
#      'ATP6V1F',
#      'ATXN8OS',
#      'B2M',
#      'C19orf43',
#      'CACYBP',
#      'CAPG',
#      'CAPZB',
#      'CCDC85B',
#      'CCL5',
#      'CD160',
#      'CD3D',
#      'CD3E',
#      'CD52',
#      'CD7',
#      'CLIC1',
#      'CTSW',
#      'CXCR3',
#      'CYTIP',
#      'DHRS7',
#      'ECH1',
#      'EEF1A1',
#      'ENO1',
#      'GAPDH',
#      'GNB2L1',
#      'GUK1',
#      'HLA-A',
#      'HLA-C',
#      'HLA-G',
#      'HOPX',
#      'IFITM1',
#      'IGHV1OR15-1',
#      'IL32',
#      'JUNB',
#      'LY6E',
#      'MAD2L2',
#      'MIF',
#      'MRPL24',
#      'MYL12A',
#      'MYL12B',
#      'PFN1',
#      'PLP2',
#      'PPDPF',
#      'PPP1R11',
#      'PSMB10',
#      'PSMD9',
#      'PSME2',
#      'PTGER2',
#      'RAB33A',
#      'RABAC1',
#      'RAC2',
#      'RHOC',
#      'RNA18S5',
#      'RPL10',
#      'RPL10A',
#      'RPL11',
#      'RPL12',
#      'RPL13',
#      'RPL13A',
#      'RPL14',
#      'RPL18A',
#      'RPL19',
#      'RPL3',
#      'RPL32',
#      'RPL4',
#      'RPL5',
#      'RPL6',
#      'RPL7',
#      'RPL8',
#      'RPLP0',
#      'RPS14',
#      'RPS18',
#      'RPS19',
#      'RPS2',
#      'RPS3',
#      'RPS4X',
#      'RPS5',
#      'RPS6',
#      'RPSA',
#      'SH3BGRL3',
#      'SMDT1',
#      'TECR',
#      'TMSB4X',
#      'TPI1',
#      'TRAC',
#      'TRBC2',
#      'TSR2',
#      'TUBA1A',
#      'TUBB',
#      'VAMP8',
#      'XCL1',
#      'ZFP36']},
#    'HLM_result_2':              estimate         p_val    z_score  p_adjust     up program
#    AAK1        15.222242  2.010496e-65  64.997727       NaN   True    MCP2
#    AAMP       -18.127834  8.770686e-84 -83.357996       NaN   True    MCP2
#    ABCE1        9.618649  5.048266e-53  52.597888       NaN   True    MCP2
#    AC009501.4  -7.269614  1.561783e-59 -59.107409       NaN   True    MCP2
#    AC016831.7  11.598820  6.850466e-50  49.465310       NaN   True    MCP2
#    ...               ...           ...        ...       ...    ...     ...
#    ZNF331     -47.941267  3.562708e-80 -79.749250       NaN   True    MCP2
#    ZNF428     -13.500170  8.630401e-28 -27.364999       NaN   True    MCP2
#    ZNF430      26.668644  2.297817e-77  76.939715       NaN   True    MCP2
#    ZRSR2        7.774032  1.089047e-51  51.263983       NaN   True    MCP2
#    ANXA1       -1.996889  8.097950e-82 -81.392655       NaN  False    MCP2
#
#    [448 rows x 6 columns],
#    'sig_genes_2': {'MCP2.up': ['AAK1',
#      'ABCE1',
#      'AC016831.7',
#      'AC092580.4',
#      'ACYP2',
#      'AKAP8L',
#      'ALOX5AP',
#      'ARFGAP3',
#      'ARHGEF3',
#      'ARIH2',
#      'ARL3',
#      'ARL6IP1',
#      'ARPC4',
#      'ASB2',
#      'ATF6B',
#      'ATP5I',
#      'ATP5L',
#      'ATP8A1',
#      'BCAP31',
#      'BCAS4',
#      'BCL11B',
#      'BID',
#      'BTG1',
#      'C14orf2',
#      'C5orf28',
#      'CALCOCO2',
#      'CARS',
#      'CBX6',
#      'CCDC25',
#      'CCDC69',
#      'CD2',
#      'CD5',
#      'CD53',
#      'CDKN1B',
#      'CHD1',
#      'CHMP3',
#      'CHMP4A',
#      'CHRAC1',
#      'CHURC1',
#      'CLEC2B',
#      'CLEC2D',
#      'CNDP2',
#      'CNOT11',
#      'COA5',
#      'COQ5',
#      'COX7B',
#      'CTBP1',
#      'CUTA',
#      'CYBA',
#      'CYFIP2',
#      'DCAF5',
#      'DEK',
#      'DSTN',
#      'EEF1E1',
#      'EI24',
#      'EIF3J',
#      'EIF4H',
#      'EIF5',
#      'EML4',
#      'ENO1',
#      'EPS15',
#      'FAM65B',
#      'FKBP1A',
#      'FNBP4',
#      'FXR1',
#      'FYB',
#      'FYN',
#      'GADD45G',
#      'GANAB',
#      'GLG1',
#      'GLTP',
#      'GPATCH8',
#      'GPR171',
#      'GPX1',
#      'H1FX',
#      'HADHA',
#      'HAVCR2',
#      'HDAC10',
#      'HIC1',
#      'HNRNPA3',
#      'HSH2D',
#      'HSPB11',
#      'IFT20',
#      'ILF3',
#      'INPP4A',
#      'IP6K2',
#      'KLHDC2',
#      'KLRB1',
#      'LIMD2',
#      'LINS',
#      'LLPH',
#      'LOH12CR1',
#      'LPIN1',
#      'LRRC59',
#      'LUZP1',
#      'MACF1',
#      'MAF',
#      'MAP1LC3B2',
#      'MDFIC',
#      'MGST3',
#      'MIER1',
#      'MLEC',
#      'MLLT6',
#      'MRPL1',
#      'MRPL19',
#      'MRPL33',
#      'MRPL42',
#      'MRPS26',
#      'MRPS36',
#      'MSMO1',
#      'MT-ATP6',
#      'MT-ND3',
#      'MT1X',
#      'MTDH',
#      'MTPN',
#      'MYL12A',
#      'MYL12B',
#      'NAP1L4',
#      'NCOA7',
#      'NDRG3',
#      'NDUFA3',
#      'NDUFB1',
#      'NGLY1',
#      'NHP2L1',
#      'NOP10',
#      'NUDT1',
#      'ODC1',
#      'OFD1',
#      'P2RY11',
#      'PAG1',
#      'PBRM1',
#      'PBXIP1',
#      'PCNP',
#      'POLR2B',
#      'PPAPDC1B',
#      'PPP3CA',
#      'PRDM1',
#      'PRELID1',
#      'PRPF6',
#      'PSIP1',
#      'PSMC5',
#      'PSMD14',
#      'PTPLAD1',
#      'PTPN22',
#      'PTPN7',
#      'PTPRN2',
#      'RAB27A',
#      'RAB4A',
#      'RAE1',
#      'RASGRP1',
#      'RBX1',
#      'RICTOR',
#      'RIN3',
#      'RNF213',
#      'RORA',
#      'RP11-347P5.1',
#      'RP11-349A22.5',
#      'RPL10A',
#      'RPL18A',
#      'RPL19',
#      'RPL29',
#      'RPL34',
#      'RPL37',
#      'RPL38',
#      'RPL39',
#      'RPL7A',
#      'RPLP0',
#      'RPS10',
#      'RPS27',
#      'RPS29',
#      'RPS7',
#      'RPSA',
#      'RTF1',
#      'SCCPDH',
#      'SDHC',
#      'SEC22B',
#      'SEPT2',
#      'SERTAD1',
#      'SET',
#      'SETD5',
#      'SF3B2',
#      'SFXN1',
#      'SHOC2',
#      'SIPA1',
#      'SKA2',
#      'SLA',
#      'SLC35A4',
#      'SLC44A2',
#      'SLITRK4',
#      'SMARCE1',
#      'SMC5',
#      'SMEK2',
#      'SNRPD1',
#      'SON',
#      'SORL1',
#      'SPN',
#      'SPNS3',
#      'SPOCK2',
#      'SPTY2D1',
#      'SRP72',
#      'SRRM2',
#      'SRSF11',
#      'SRSF9',
#      'STK17B',
#      'STX5',
#      'SUB1',
#      'SYF2',
#      'SYNRG',
#      'TAPBP',
#      'TAX1BP1',
#      'TBC1D10C',
#      'TBL1XR1',
#      'TCF25',
#      'TDG',
#      'TFAM',
#      'TFDP1',
#      'TIMM22',
#      'TMED2',
#      'TMEM106C',
#      'TMEM167A',
#      'TMEM170A',
#      'TMEM2',
#      'TMEM218',
#      'TMEM258',
#      'TMEM87A',
#      'TNIP3',
#      'TNRC6B',
#      'TOP1',
#      'TOX',
#      'TPMT',
#      'TPP1',
#      'TRA2B',
#      'TSPYL1',
#      'TTC14',
#      'TTC39C',
#      'TUBA1B',
#      'TXNDC17',
#      'U2SURP',
#      'UPF3B',
#      'UQCC2',
#      'UQCR10',
#      'UQCRB',
#      'UQCRH',
#      'USF2',
#      'USMG5',
#      'USP14',
#      'USP15',
#      'USP16',
#      'USP36',
#      'VAMP5',
#      'VOPP1',
#      'VPS13C',
#      'VPS25',
#      'VPS51',
#      'XIST',
#      'ZBTB8OS',
#      'ZFP36L1',
#      'ZNF430',
#      'ZRSR2'],
#     'MCP2.down': ['AAMP',
#      'AC009501.4',
#      'AGA',
#      'AL136419.6',
#      'ANKRD13D',
#      'ANXA1',
#      'AP1S1',
#      'ATG3',
#      'ATXN10',
#      'ATXN8OS',
#      'C16orf91',
#      'C6orf1',
#      'CCDC101',
#      'CCL5',
#      'CD27',
#      'CD48',
#      'CITED2',
#      'CLK3',
#      'CMC1',
#      'COPS3',
#      'CXCR4',
#      'DCTD',
#      'DHRS7',
#      'DNAJA1',
#      'DUSP2',
#      'EEF1A1',
#      'EIF5A',
#      'ETNK1',
#      'FOSB',
#      'FXYD5',
#      'GBP1',
#      'HLA-G',
#      'HTATIP2',
#      'INO80C',
#      'ITGB2',
#      'KIF22',
#      'KLRG1',
#      'KMT2A',
#      'LDHA',
#      'LGALS1',
#      'LYSMD2',
#      'MAN1B1',
#      'METTL17',
#      'MIF',
#      'MRPS23',
#      'MSN',
#      'MX1',
#      'MYO9B',
#      'NCF1',
#      'NDUFAF3',
#      'NXT1',
#      'PCED1B-AS1',
#      'PIM3',
#      'PLAC8',
#      'PLP2',
#      'PMAIP1',
#      'PSMB3',
#      'PTGER4',
#      'RBM33',
#      'RGCC',
#      'RNF125',
#      'RNF139',
#      'RPL10',
#      'RPL12',
#      'RPL13',
#      'RPL13A',
#      'RPL15',
#      'RPL6',
#      'RPS2',
#      'RPS6',
#      'RPS9',
#      'RSU1',
#      'RWDD1',
#      'S100A11',
#      'SH3GLB1',
#      'SIGIRR',
#      'SLC2A4RG',
#      'SMDT1',
#      'SMG1',
#      'SMPD1',
#      'SMYD2',
#      'SNRNP25',
#      'TAGAP',
#      'TAZ',
#      'TMEM14A',
#      'TMEM199',
#      'TSC22D3',
#      'VIM',
#      'VPS4A',
#      'XCL1',
#      'ZFP36L2',
#      'ZNF331']}},
#   'MCP3': {'HLM_result_1':              estimate         p_val   z_score  p_adjust     up program
#    ABCF1       15.745325  1.467139e-05  5.134559  0.000031   True    MCP3
#    AC009501.4  -3.675818  9.404850e-07 -6.327678  0.000006   True    MCP3
#    AC020571.3  19.340048  1.466591e-04  4.134721  0.000234   True    MCP3
#    ACTB       -16.751653  1.499591e-05 -5.125057  0.000032   True    MCP3
#    ACTG1       -3.511348  1.545214e-03 -3.112041  0.002027   True    MCP3
#    ...               ...           ...       ...       ...    ...     ...
#    YY1          9.857854  1.592445e-04  4.098965  0.000253   True    MCP3
#    ZC3HAV1     12.457997  8.773014e-05  4.357881  0.000148   True    MCP3
#    ZEB2        15.444480  1.002919e-01  1.299764  0.103013   True    MCP3
#    ZFP36       -4.550948  7.089079e-05 -4.450440  0.000124   True    MCP3
#    TTC19        5.392597  1.459383e-02  2.136861  0.016888  False    MCP3
#
#    [265 rows x 6 columns],
#    'sig_genes_1': {'MCP3.up': ['ABCF1',
#      'AC020571.3',
#      'AHNAK',
#      'ANKRD11',
#      'ANKRD36',
#      'ANKRD36C',
#      'AP3D1',
#      'ARAP2',
#      'ARF6',
#      'ARGLU1',
#      'ATF4',
#      'ATM',
#      'ATP5I',
#      'ATP8A1',
#      'ATRX',
#      'BROX',
#      'C16orf54',
#      'C8orf59',
#      'CBX5',
#      'CCDC66',
#      'CMC1',
#      'COX20',
#      'CREM',
#      'DDX3X',
#      'DNMT1',
#      'FAM172A',
#      'FAM45A',
#      'FNBP1',
#      'GADD45G',
#      'GPRIN3',
#      'HEXIM1',
#      'HIST1H4C',
#      'HNRNPD',
#      'HP1BP3',
#      'IFNG',
#      'KIF20B',
#      'KLF2',
#      'KMT2E',
#      'LNPEP',
#      'LRMP',
#      'LYST',
#      'MAP4',
#      'MARCH6',
#      'MBNL1',
#      'MCL1',
#      'MGEA5',
#      'MT1X',
#      'MTMR9',
#      'MYCBP2',
#      'NDUFA3',
#      'NR4A2',
#      'NUP50',
#      'OGT',
#      'PCM1',
#      'PHACTR2',
#      'PHIP',
#      'PIK3R1',
#      'PNPLA8',
#      'POMP',
#      'PPP1R10',
#      'PPP2R5C',
#      'PSD4',
#      'PTP4A2',
#      'RAB11FIP1',
#      'RASGRP1',
#      'RICTOR',
#      'RNF168',
#      'RNMT',
#      'RORA',
#      'RP11-349A22.5',
#      'SAMD9',
#      'SAR1A',
#      'SEC62',
#      'SENP6',
#      'SETD5',
#      'SFXN1',
#      'SHFM1',
#      'SKA2',
#      'SKIL',
#      'SLA',
#      'SLC38A2',
#      'SMARCE1',
#      'SMC1A',
#      'SMEK1',
#      'SMG1',
#      'SON',
#      'SRSF5',
#      'SYAP1',
#      'TATDN1',
#      'TBC1D2B',
#      'TBRG1',
#      'TM2D1',
#      'TNFRSF25',
#      'TRIM13',
#      'UBA6',
#      'UHMK1',
#      'UPF2',
#      'UTRN',
#      'YTHDC1',
#      'YY1',
#      'ZC3HAV1'],
#     'MCP3.down': ['AC009501.4',
#      'ACTB',
#      'ALDOA',
#      'ANXA1',
#      'ANXA5',
#      'ARF5',
#      'ARHGDIB',
#      'ARL2',
#      'ARPC1B',
#      'ATP5A1',
#      'ATP6V1F',
#      'ATXN8OS',
#      'B2M',
#      'C19orf43',
#      'CACYBP',
#      'CAPG',
#      'CAPZB',
#      'CCDC85B',
#      'CCL5',
#      'CD160',
#      'CD3D',
#      'CD3E',
#      'CD52',
#      'CD7',
#      'CLIC1',
#      'CTSW',
#      'CXCR3',
#      'CYTIP',
#      'DHRS7',
#      'ECH1',
#      'EEF1A1',
#      'ENO1',
#      'GAPDH',
#      'GNB2L1',
#      'GUK1',
#      'HLA-A',
#      'HLA-C',
#      'HLA-G',
#      'HOPX',
#      'IFITM1',
#      'IGHV1OR15-1',
#      'IL32',
#      'JUNB',
#      'LY6E',
#      'MAD2L2',
#      'MIF',
#      'MRPL24',
#      'MYL12A',
#      'MYL12B',
#      'PFN1',
#      'PLP2',
#      'PPDPF',
#      'PPP1R11',
#      'PSMB10',
#      'PSMD9',
#      'PSME2',
#      'PTGER2',
#      'RAB33A',
#      'RABAC1',
#      'RAC2',
#      'RHOC',
#      'RNA18S5',
#      'RPL10',
#      'RPL10A',
#      'RPL11',
#      'RPL12',
#      'RPL13',
#      'RPL13A',
#      'RPL14',
#      'RPL18A',
#      'RPL19',
#      'RPL3',
#      'RPL32',
#      'RPL4',
#      'RPL5',
#      'RPL6',
#      'RPL7',
#      'RPL8',
#      'RPLP0',
#      'RPS14',
#      'RPS18',
#      'RPS19',
#      'RPS2',
#      'RPS3',
#      'RPS4X',
#      'RPS5',
#      'RPS6',
#      'RPSA',
#      'SH3BGRL3',
#      'SMDT1',
#      'TECR',
#      'TMSB4X',
#      'TPI1',
#      'TRAC',
#      'TRBC2',
#      'TSR2',
#      'TUBA1A',
#      'TUBB',
#      'VAMP8',
#      'XCL1',
#      'ZFP36']},
#    'HLM_result_2':              estimate         p_val    z_score      p_adjust    up program
#    AAK1        14.841955  5.338688e-65  64.573595  1.150669e-64  True    MCP3
#    AAMP       -17.652058  8.437036e-83 -82.374840  9.136693e-82  True    MCP3
#    ABCE1        9.322626  7.304924e-52  51.437414  1.233227e-51  True    MCP3
#    AC009501.4  -7.070637  1.282720e-57 -57.192898  2.334130e-57  True    MCP3
#    AC016831.7  11.240851  1.041782e-48  48.283253  1.622987e-48  True    MCP3
#    ...               ...           ...        ...           ...   ...     ...
#    ZNF259     -14.580378  2.494374e-14 -13.904068  2.810919e-14  True    MCP3
#    ZNF331     -46.698647  2.518165e-79 -78.899946  1.085500e-78  True    MCP3
#    ZNF428     -13.182152  1.099040e-27 -27.260016  1.366873e-27  True    MCP3
#    ZNF430      25.953852  1.333404e-76  76.176068  4.589390e-76  True    MCP3
#    ZRSR2        7.534498  1.612782e-50  50.093454  2.642344e-50  True    MCP3
#
#    [444 rows x 6 columns],
#    'sig_genes_2': {'MCP3.up': ['ACYP2',
#      'ARFGAP3',
#      'ARHGEF3',
#      'ARL6IP1',
#      'ARPC4',
#      'ASB2',
#      'ATF6B',
#      'ATP5L',
#      'BTG1',
#      'C14orf2',
#      'CARS',
#      'CDKN1B',
#      'CHD1',
#      'CHURC1',
#      'CLEC2B',
#      'CLEC2D',
#      'COA5',
#      'DEK',
#      'DSTN',
#      'FKBP1A',
#      'FYB',
#      'FYN',
#      'GADD45G',
#      'GANAB',
#      'GPR171',
#      'HADHA',
#      'HAVCR2',
#      'HIC1',
#      'HNRNPA3',
#      'HSH2D',
#      'ILF3',
#      'IP6K2',
#      'KLHDC2',
#      'LIMD2',
#      'LINS',
#      'LPIN1',
#      'LRRC59',
#      'MRPL33',
#      'MT-ATP6',
#      'MTDH',
#      'MYL12A',
#      'NGLY1',
#      'PBRM1',
#      'PCNP',
#      'PPP3CA',
#      'PRPF6',
#      'PSIP1',
#      'PSMD14',
#      'PTPLAD1',
#      'PTPN22',
#      'PTPN7',
#      'RAB27A',
#      'RASGRP1',
#      'RIN3',
#      'RP11-347P5.1',
#      'RP11-349A22.5',
#      'RPL18A',
#      'RPL37',
#      'RPL38',
#      'RPS10',
#      'RPS27',
#      'RPS29',
#      'RPS7',
#      'RTF1',
#      'SDHC',
#      'SEC22B',
#      'SEPT2',
#      'SETD5',
#      'SFXN1',
#      'SHOC2',
#      'SIPA1',
#      'SKA2',
#      'SMARCE1',
#      'SMEK2',
#      'SPNS3',
#      'SRP72',
#      'STK17B',
#      'SUB1',
#      'SYF2',
#      'SYNRG',
#      'TAPBP',
#      'TAX1BP1',
#      'TDG',
#      'TFAM',
#      'TIMM22',
#      'TMED2',
#      'TMEM2',
#      'TMEM258',
#      'TNRC6B',
#      'TOX',
#      'TPP1',
#      'TRA2B',
#      'TXNDC17',
#      'UQCR10',
#      'UQCRB',
#      'UQCRH',
#      'USMG5',
#      'VAMP5',
#      'VPS25',
#      'ZBTB8OS',
#      'ZNF430'],
#     'MCP3.down': ['AAMP',
#      'AC009501.4',
#      'AGA',
#      'AL136419.6',
#      'ANKRD13D',
#      'ANXA1',
#      'AP1S1',
#      'ARMCX6',
#      'ATG3',
#      'ATXN10',
#      'ATXN8OS',
#      'B3GNT2',
#      'C16orf91',
#      'C6orf1',
#      'CCDC101',
#      'CCL5',
#      'CD27',
#      'CD48',
#      'CITED2',
#      'CLIC1',
#      'CLK3',
#      'CMC1',
#      'COPS3',
#      'CXCR4',
#      'DCTD',
#      'DHRS7',
#      'DNAJA1',
#      'DUSP2',
#      'EEF1A1',
#      'EIF5A',
#      'ETNK1',
#      'FOSB',
#      'FXYD5',
#      'GAPDH',
#      'GBP1',
#      'HLA-G',
#      'HTATIP2',
#      'INO80C',
#      'ITGB2',
#      'KANSL2',
#      'KIF22',
#      'KLRG1',
#      'KMT2A',
#      'LDHA',
#      'LGALS1',
#      'LYSMD2',
#      'MAN1B1',
#      'METTL17',
#      'MIF',
#      'MPLKIP',
#      'MRPS23',
#      'MSN',
#      'MX1',
#      'MYO9B',
#      'NCF1',
#      'NDUFAF3',
#      'NXT1',
#      'PCED1B-AS1',
#      'PIM3',
#      'PLAC8',
#      'PLP2',
#      'PMAIP1',
#      'PPHLN1',
#      'PSMB3',
#      'PTGER4',
#      'RBM33',
#      'RGCC',
#      'RNF125',
#      'RNF139',
#      'RPL10',
#      'RPL12',
#      'RPL13',
#      'RPL13A',
#      'RPL14',
#      'RPL15',
#      'RPL6',
#      'RPS2',
#      'RPS5',
#      'RPS6',
#      'RPS9',
#      'RSU1',
#      'RWDD1',
#      'S100A11',
#      'SH3GLB1',
#      'SIGIRR',
#      'SLC2A4RG',
#      'SMDT1',
#      'SMG1',
#      'SMPD1',
#      'SMYD2',
#      'SNRNP25',
#      'TAGAP',
#      'TAZ',
#      'TMEM14A',
#      'TMEM199',
#      'TSC22D3',
#      'VIM',
#      'VPS4A',
#      'XCL1',
#      'ZFP36L2',
#      'ZNF331']}}},
#  'CD8+ IELs_vs_CD8+ LP': {'MCP1': {'HLM_result_1':              estimate          p_val     z_score       p_adjust    up program
#    AAK1        18.141673  9.091198e-107  106.342409  1.297602e-105  True    MCP1
#    ABCE1       22.085727   1.172953e-83   83.231749   2.126505e-83  True    MCP1
#    ABCF1       23.531255  8.024519e-102  101.396611  2.696238e-101  True    MCP1
#    AC020571.3  31.960075   4.346692e-91   90.662871   9.204759e-91  True    MCP1
#    AC092580.4   5.493550   6.778064e-94   93.469924   1.596329e-93  True    MCP1
#    ...               ...            ...         ...            ...   ...     ...
#    YWHAZ       10.163922   2.071987e-94   93.984643   5.069326e-94  True    MCP1
#    YY1         13.880571   7.984115e-51   50.398803   9.862730e-51  True    MCP1
#    ZC3HAV1     20.095101   7.768174e-94   93.410711   1.812574e-93  True    MCP1
#    ZEB2        43.372318   1.773833e-36   36.052117   1.977902e-36  True    MCP1
#    ZNF644      28.143555  5.507300e-106  105.560091  4.476902e-105  True    MCP1
#
#    [252 rows x 6 columns],
#    'sig_genes_1': {'MCP1.up': ['AAK1',
#      'ABCF1',
#      'AC092580.4',
#      'ACTR2',
#      'ANKRD36',
#      'ARAP2',
#      'ARF6',
#      'ARGLU1',
#      'ATF4',
#      'ATM',
#      'ATP8A1',
#      'BPTF',
#      'C16orf54',
#      'CAPZA1',
#      'CLEC2B',
#      'COX7B',
#      'COX7C',
#      'CREM',
#      'DDX3X',
#      'DNMT1',
#      'EIF3E',
#      'ELF1',
#      'FAM45A',
#      'FNBP1',
#      'FYB',
#      'GPR65',
#      'GPRIN3',
#      'HIST1H4C',
#      'HNRNPD',
#      'HNRNPH1',
#      'HP1BP3',
#      'IFNG',
#      'IQGAP1',
#      'ITK',
#      'IWS1',
#      'KLF2',
#      'KLRB1',
#      'KLRD1',
#      'KMT2E',
#      'LNPEP',
#      'LRMP',
#      'MARCH6',
#      'MBNL1',
#      'MCL1',
#      'MDM4',
#      'MT-ND3',
#      'MT1X',
#      'MTMR9',
#      'MYCBP2',
#      'N4BP2L2',
#      'NCL',
#      'NDUFA3',
#      'NUP50',
#      'OGT',
#      'PAG1',
#      'PCM1',
#      'PHACTR2',
#      'PHIP',
#      'PIK3R1',
#      'PIP4K2A',
#      'PNPLA8',
#      'POMP',
#      'PPP1CB',
#      'PPP3CA',
#      'PTPRC',
#      'RASGRP1',
#      'RBPJ',
#      'RICTOR',
#      'RNMT',
#      'RORA',
#      'RP11-347P5.1',
#      'RP11-349A22.5',
#      'RPL39',
#      'RPS29',
#      'SAMD3',
#      'SEC61G',
#      'SET',
#      'SETD5',
#      'SFPQ',
#      'SFXN1',
#      'SHFM1',
#      'SKIL',
#      'SLA',
#      'SLC38A2',
#      'SMCHD1',
#      'SMG1',
#      'SON',
#      'SRSF5',
#      'SRSF6',
#      'SUB1',
#      'SYAP1',
#      'TBC1D2B',
#      'TM2D1',
#      'TNRC6B',
#      'TRA2A',
#      'TRIM13',
#      'UPF2',
#      'XIST',
#      'YWHAZ',
#      'ZC3HAV1',
#      'ZNF644'],
#     'MCP1.down': ['ALDOA',
#      'ANXA1',
#      'ANXA5',
#      'ARF5',
#      'ARL2',
#      'ARPC2',
#      'ATP5A1',
#      'ATP5G2',
#      'CACYBP',
#      'CAPZB',
#      'CD37',
#      'CD52',
#      'EMP3',
#      'IGHV1OR15-1',
#      'MAD2L2',
#      'MIF',
#      'NBEAL1',
#      'PABPC1',
#      'PKM',
#      'PLP2',
#      'PPP1R11',
#      'PSMD9',
#      'PTGER2',
#      'RAB33A',
#      'RPL10A',
#      'RPL17',
#      'RPS14',
#      'RPS18',
#      'RPSA',
#      'SIRPG',
#      'TECR',
#      'TRAC',
#      'TRGC2',
#      'TSR2',
#      'TUBA1A',
#      'TUBB']},
#    'HLM_result_2':               estimate         p_val    z_score      p_adjust     up program
#    AAK1         31.470315  9.672664e-84  83.315484  3.333148e-83   True    MCP1
#    AC013394.2   18.827203  2.008129e-62  61.998238  2.485791e-62   True    MCP1
#    AC016831.7   30.613637  4.924599e-83  82.608659  1.308097e-82   True    MCP1
#    AKNA         53.517622  2.148059e-72  71.968984  3.279970e-72   True    MCP1
#    ANKRD11      17.047650  2.107667e-83  82.977228  6.249478e-83   True    MCP1
#    ...                ...           ...        ...           ...    ...     ...
#    ZBTB38      121.157026  3.013319e-84  83.821985  1.275431e-83   True    MCP1
#    ZBTB7A       56.158547  3.093742e-84  83.810546  1.275431e-83   True    MCP1
#    ZEB2         30.798060  8.919628e-82  81.350683  1.977831e-81   True    MCP1
#    ZMYM2        27.827350  7.500104e-71  70.425963  1.099153e-70   True    MCP1
#    TPI1        -23.538466  3.023362e-74 -73.820540  4.973919e-74  False    MCP1
#
#    [255 rows x 6 columns],
#    'sig_genes_2': {'MCP1.up': ['AAK1',
#      'AC016831.7',
#      'ANKRD11',
#      'ANKRD36',
#      'APOL6',
#      'ARID4B',
#      'ATM',
#      'ATP5E',
#      'ATRX',
#      'BAZ1B',
#      'BCL11B',
#      'BRD2',
#      'C14orf2',
#      'C1orf56',
#      'C6orf62',
#      'CAPZA1',
#      'CCDC66',
#      'CCNL1',
#      'CCSER2',
#      'CD44',
#      'CD81',
#      'CDC42',
#      'CEBPZ',
#      'CMC1',
#      'CNOT4',
#      'DDX17',
#      'DDX3X',
#      'DGKZ',
#      'DHX36',
#      'ELF1',
#      'EML4',
#      'FNBP4',
#      'FUS',
#      'FYB',
#      'GOLGA4',
#      'GPBP1',
#      'GTF2H5',
#      'HEXIM1',
#      'HNRNPD',
#      'HNRNPH1',
#      'HSP90B1',
#      'HSPD1',
#      'HSPH1',
#      'JAK1',
#      'KLF2',
#      'KTN1',
#      'MALAT1',
#      'MAP2K2',
#      'MYCBP2',
#      'NCL',
#      'NDUFS6',
#      'NEAT1',
#      'PCSK7',
#      'PDE7A',
#      'PHF17',
#      'PHIP',
#      'PNRC1',
#      'POLR2B',
#      'PRPF38B',
#      'PTEN',
#      'PTP4A2',
#      'PTPRC',
#      'PYHIN1',
#      'RBM25',
#      'ROCK1',
#      'RP11-138A9.2',
#      'RP11-94L15.2',
#      'RPL23',
#      'RPL37',
#      'RPL39',
#      'RPS11',
#      'RPS24',
#      'RPS26',
#      'RPS29',
#      'RTF1',
#      'RUNX3',
#      'SAFB2',
#      'SET',
#      'SFPQ',
#      'SKA2',
#      'SNHG7',
#      'SON',
#      'SORL1',
#      'SP3',
#      'STK17B',
#      'TAOK1',
#      'TAPBP',
#      'TOMM7',
#      'TRA2A',
#      'TRA2B',
#      'TSPYL1',
#      'U2SURP',
#      'UQCRB',
#      'VMP1',
#      'WIPF1',
#      'WNK1',
#      'XIST',
#      'YTHDC1',
#      'YWHAZ',
#      'ZBTB38',
#      'ZBTB7A'],
#     'MCP1.down': ['ATP5EP2',
#      'BHLHE40',
#      'BUB3',
#      'CD160',
#      'CD8B',
#      'DCTN3',
#      'DHRS7',
#      'ECH1',
#      'EMC6',
#      'FLT3LG',
#      'GHITM',
#      'GZMB',
#      'HNRNPA0',
#      'HNRNPA1',
#      'IFNGR1',
#      'LGALS1',
#      'LMAN2',
#      'LSP1',
#      'MCL1',
#      'MDH1',
#      'NAA20',
#      'NACA2',
#      'NAPA',
#      'NDUFA4',
#      'NDUFV2',
#      'OBFC1',
#      'PDLIM2',
#      'PFDN5',
#      'PSMA5',
#      'RAC2',
#      'RP1-17K7.2',
#      'RPL21',
#      'RPS10',
#      'RPS14',
#      'RPSAP58',
#      'SNORA67',
#      'SUSD3',
#      'TPI1',
#      'TRAPPC1',
#      'TXNDC12']}},
#   'MCP2': {'HLM_result_1':              estimate          p_val     z_score       p_adjust     up program
#    AAK1        18.411376  2.026923e-107  106.994193  4.383220e-106   True    MCP2
#    ABCE1       22.287540   2.644685e-82   81.878656   5.112072e-82   True    MCP2
#    ABCF1       23.813027  4.074448e-101  100.690961  1.483957e-100   True    MCP2
#    AC020571.3  32.285684   7.182743e-90   89.444740   1.624333e-89   True    MCP2
#    AC092580.4   5.551810   9.286022e-93   92.333200   2.362473e-92   True    MCP2
#    ...               ...            ...         ...            ...    ...     ...
#    VAMP8       -8.759721   1.745392e-62  -62.059137   2.447570e-62  False    MCP2
#    VIM         -5.265190   4.140160e-38  -37.684013   4.790955e-38  False    MCP2
#    XCL1        -9.953742  5.391601e-106 -105.569312  4.549985e-105  False    MCP2
#    YBX1        -7.506743   1.085783e-32  -32.265287   1.192638e-32  False    MCP2
#    ZFP36       -6.496247   3.984979e-58  -57.700604   5.364992e-58  False    MCP2
#
#    [346 rows x 6 columns],
#    'sig_genes_1': {'MCP2.up': ['AAK1',
#      'ABCF1',
#      'AC092580.4',
#      'ACTR2',
#      'ANKRD36',
#      'ARAP2',
#      'ARF6',
#      'ARGLU1',
#      'ATF4',
#      'ATM',
#      'ATP8A1',
#      'BPTF',
#      'C16orf54',
#      'CAPZA1',
#      'CLEC2B',
#      'COX7B',
#      'COX7C',
#      'CREM',
#      'DDX3X',
#      'DNMT1',
#      'EIF3E',
#      'ELF1',
#      'FAM45A',
#      'FNBP1',
#      'FYB',
#      'GPR65',
#      'GPRIN3',
#      'HEXIM1',
#      'HIST1H4C',
#      'HNRNPD',
#      'HNRNPH1',
#      'HP1BP3',
#      'IFNG',
#      'IQGAP1',
#      'ITK',
#      'IWS1',
#      'KLF2',
#      'KLRB1',
#      'KLRD1',
#      'KMT2E',
#      'LNPEP',
#      'LRMP',
#      'MARCH6',
#      'MBNL1',
#      'MCL1',
#      'MDM4',
#      'MT-ND3',
#      'MT1X',
#      'MTMR9',
#      'MYCBP2',
#      'N4BP2L2',
#      'NCL',
#      'NDUFA3',
#      'NUP50',
#      'OGT',
#      'PAG1',
#      'PCM1',
#      'PHACTR2',
#      'PHIP',
#      'PIK3R1',
#      'PIP4K2A',
#      'PNPLA8',
#      'POMP',
#      'PPP1CB',
#      'PPP3CA',
#      'PTPRC',
#      'RASGRP1',
#      'RBPJ',
#      'RICTOR',
#      'RNMT',
#      'RORA',
#      'RP11-347P5.1',
#      'RP11-349A22.5',
#      'RPL39',
#      'RPS29',
#      'SAMD3',
#      'SEC61G',
#      'SET',
#      'SETD5',
#      'SFPQ',
#      'SFXN1',
#      'SHFM1',
#      'SKIL',
#      'SLA',
#      'SLC38A2',
#      'SMCHD1',
#      'SMG1',
#      'SON',
#      'SRSF5',
#      'SRSF6',
#      'SUB1',
#      'SYAP1',
#      'TBC1D2B',
#      'TM2D1',
#      'TNRC6B',
#      'TRA2A',
#      'TRIM13',
#      'UPF2',
#      'XIST',
#      'YWHAZ',
#      'ZNF644'],
#     'MCP2.down': ['AC009501.4',
#      'ACTB',
#      'ALDOA',
#      'ANXA1',
#      'ANXA5',
#      'ARF5',
#      'ARHGDIB',
#      'ARL2',
#      'ARPC1B',
#      'ATP5A1',
#      'ATP6V1F',
#      'ATXN8OS',
#      'B2M',
#      'C19orf43',
#      'CACYBP',
#      'CAPG',
#      'CAPZB',
#      'CCL5',
#      'CD160',
#      'CD3D',
#      'CD3E',
#      'CD52',
#      'CD7',
#      'CLIC1',
#      'CTSW',
#      'CXCR3',
#      'CYTIP',
#      'DHRS7',
#      'ECH1',
#      'EEF1A1',
#      'EMP3',
#      'ENO1',
#      'GAPDH',
#      'GNB2L1',
#      'GUK1',
#      'HLA-A',
#      'HLA-C',
#      'HLA-G',
#      'HOPX',
#      'IFITM1',
#      'IGHV1OR15-1',
#      'IL32',
#      'JUNB',
#      'LY6E',
#      'MAD2L2',
#      'MIF',
#      'MRPL24',
#      'MYL12A',
#      'MYL12B',
#      'PFN1',
#      'PLP2',
#      'PPDPF',
#      'PPP1R11',
#      'PSMB10',
#      'PSMD9',
#      'PSME2',
#      'PTGER2',
#      'RAB33A',
#      'RABAC1',
#      'RAC2',
#      'RHOC',
#      'RNA18S5',
#      'RPL10',
#      'RPL10A',
#      'RPL11',
#      'RPL12',
#      'RPL13',
#      'RPL13A',
#      'RPL14',
#      'RPL18A',
#      'RPL19',
#      'RPL3',
#      'RPL32',
#      'RPL4',
#      'RPL5',
#      'RPL6',
#      'RPL7',
#      'RPL8',
#      'RPLP0',
#      'RPS14',
#      'RPS18',
#      'RPS19',
#      'RPS2',
#      'RPS3',
#      'RPS4X',
#      'RPS5',
#      'RPS6',
#      'RPSA',
#      'SH3BGRL3',
#      'SMDT1',
#      'TECR',
#      'TMSB4X',
#      'TPI1',
#      'TRAC',
#      'TRBC2',
#      'TSR2',
#      'TUBA1A',
#      'TUBB',
#      'VAMP8',
#      'XCL1',
#      'ZFP36']},
#    'HLM_result_2':              estimate         p_val    z_score  p_adjust     up program
#    AAK1        30.957272  1.352989e-83  83.169736       NaN   True    MCP2
#    AC013394.2  18.547006  1.057432e-62  62.276778       NaN   True    MCP2
#    AC016831.7  29.885048  5.609637e-80  79.552095       NaN   True    MCP2
#    AKNA        52.684043  1.818249e-72  72.041377       NaN   True    MCP2
#    ANKRD11     16.770183  2.907631e-83  82.837491       NaN   True    MCP2
#    ...               ...           ...        ...       ...    ...     ...
#    XCL1       -12.360563  2.116047e-84 -83.975505       NaN  False    MCP2
#    YPEL5       -6.755459  1.357660e-78 -78.168239       NaN  False    MCP2
#    ZFP36       -5.605103  3.555923e-81 -80.750078       NaN  False    MCP2
#    ZFP36L2    -13.644463  1.843000e-45 -45.035505       NaN  False    MCP2
#    ZNF331     -12.500229  1.771016e-84 -84.052808       NaN  False    MCP2
#
#    [386 rows x 6 columns],
#    'sig_genes_2': {'MCP2.up': ['AAK1',
#      'ANKRD11',
#      'ANKRD36',
#      'APOL6',
#      'ATM',
#      'ATP5E',
#      'ATRX',
#      'BAZ1B',
#      'BCL11B',
#      'BRD2',
#      'C14orf2',
#      'C1orf56',
#      'C6orf62',
#      'CAPZA1',
#      'CCDC66',
#      'CCNL1',
#      'CCSER2',
#      'CD44',
#      'CD81',
#      'CDC42',
#      'CEBPZ',
#      'CMC1',
#      'CNOT4',
#      'DDX17',
#      'DDX3X',
#      'DGKZ',
#      'DHX36',
#      'ELF1',
#      'EML4',
#      'FNBP4',
#      'FUS',
#      'FYB',
#      'GADD45A',
#      'GOLGA4',
#      'GPBP1',
#      'GTF2H5',
#      'HEXIM1',
#      'HNRNPD',
#      'HNRNPH1',
#      'HSP90B1',
#      'HSPD1',
#      'HSPH1',
#      'JAK1',
#      'KCNQ1OT1',
#      'KLF2',
#      'KTN1',
#      'MALAT1',
#      'MIAT',
#      'MYCBP2',
#      'NCL',
#      'NDUFS6',
#      'NEAT1',
#      'PCSK7',
#      'PDE7A',
#      'PHF17',
#      'PHIP',
#      'POLR2B',
#      'PRPF38B',
#      'PTEN',
#      'PTP4A2',
#      'PTPRC',
#      'PYHIN1',
#      'RBM25',
#      'RBM39',
#      'RP11-138A9.2',
#      'RP11-347P5.1',
#      'RP11-94L15.2',
#      'RPL23',
#      'RPL37',
#      'RPL39',
#      'RPS11',
#      'RPS24',
#      'RPS26',
#      'RPS29',
#      'RTF1',
#      'RUNX3',
#      'SAFB2',
#      'SET',
#      'SFPQ',
#      'SKA2',
#      'SNHG7',
#      'SON',
#      'SORL1',
#      'SP3',
#      'SRRM1',
#      'STK17B',
#      'SYNRG',
#      'TAOK1',
#      'TAPBP',
#      'TNRC6C',
#      'TRA2A',
#      'TRA2B',
#      'UQCRB',
#      'VMP1',
#      'WNK1',
#      'XIST',
#      'YME1L1',
#      'YWHAZ',
#      'ZBTB38',
#      'ZBTB7A',
#      'ZEB2'],
#     'MCP2.down': ['AC009501.4',
#      'ACTB',
#      'ALOX5AP',
#      'ANXA1',
#      'ARF5',
#      'ARHGDIB',
#      'ARL4A',
#      'ARL6IP5',
#      'ARPC1B',
#      'ARPC3',
#      'ATP5EP2',
#      'ATXN8OS',
#      'BCAS2',
#      'BHLHE40',
#      'CAPG',
#      'CCL4',
#      'CCL5',
#      'CD160',
#      'CD3D',
#      'CD3E',
#      'CD52',
#      'CD69',
#      'CD8B',
#      'CD99',
#      'CFL1',
#      'CHCHD2',
#      'CIB1',
#      'CLIC1',
#      'CNBP',
#      'CTSW',
#      'CXCR4',
#      'CYBA',
#      'DCTN3',
#      'DHRS7',
#      'DNAJB9',
#      'DRAP1',
#      'ECH1',
#      'EMC6',
#      'EMP3',
#      'FLT3LG',
#      'FOS',
#      'GHITM',
#      'HLA-A',
#      'HLA-C',
#      'HLA-G',
#      'HOPX',
#      'IFITM1',
#      'IL32',
#      'JUNB',
#      'LGALS1',
#      'LMAN2',
#      'LRRC69',
#      'LTB',
#      'LY6E',
#      'MIF',
#      'MYL12A',
#      'MYL12B',
#      'MYL6',
#      'NAPA',
#      'NDUFB8',
#      'OAZ1',
#      'PCMT1',
#      'PDCL3',
#      'PDLIM2',
#      'PFDN5',
#      'PFN1',
#      'PGK1',
#      'POLR2E',
#      'PRDX2',
#      'PRR13',
#      'PSMA5',
#      'PSMB10',
#      'PSMB6',
#      'PSMB9',
#      'PSME1',
#      'PSME2',
#      'PTGER4',
#      'RAC2',
#      'RGCC',
#      'RGS2',
#      'RPL10',
#      'RPL11',
#      'RPL13',
#      'RPL13A',
#      'RPL15',
#      'RPL17',
#      'RPL19',
#      'RPL3',
#      'RPL32',
#      'RPL6',
#      'RPL8',
#      'RPLP0',
#      'RPS18',
#      'RPS2',
#      'RPS3',
#      'RPS4X',
#      'RPS4Y1',
#      'S100A10',
#      'S100A11',
#      'S100A4',
#      'SAMSN1',
#      'SELK',
#      'SH3BGRL3',
#      'SNORA67',
#      'SOCS1',
#      'SUSD3',
#      'TAGLN2',
#      'TMSB4X',
#      'TPI1',
#      'TRAPPC1',
#      'TRAPPC2P1',
#      'TSC22D3',
#      'TUBA1A',
#      'TXNDC12',
#      'UBB',
#      'UBC',
#      'VIM',
#      'XCL1',
#      'YPEL5',
#      'ZFP36',
#      'ZNF331']}},
#   'MCP3': {'HLM_result_1':              estimate          p_val     z_score       p_adjust     up program
#    ABCF1       23.673179  3.711110e-101  100.731526  3.391187e-100   True    MCP3
#    AC009501.4  -4.921032   1.025848e-95  -95.289947   3.883567e-95   True    MCP3
#    AC020571.3  32.045025   6.902768e-88   87.462007   1.725692e-87   True    MCP3
#    ACTB       -23.429621   1.534029e-70  -70.115197   2.622694e-70   True    MCP3
#    ACTG1       -5.209876   4.298478e-35  -34.667715   5.018047e-35   True    MCP3
#    ...               ...            ...         ...            ...    ...     ...
#    YY1         14.307417   2.432257e-52   51.915020   3.374598e-52   True    MCP3
#    ZC3HAV1     20.164027   8.059490e-91   90.394722   2.296521e-90   True    MCP3
#    ZEB2        42.680871   6.487835e-34   33.488930   7.442755e-34   True    MCP3
#    ZFP36       -6.527001   1.596841e-58  -58.097768   2.325070e-58   True    MCP3
#    TTC19       11.923829   8.643936e-54   53.364318   1.211980e-53  False    MCP3
#
#    [265 rows x 6 columns],
#    'sig_genes_1': {'MCP3.up': ['ABCF1',
#      'AC020571.3',
#      'ANKRD11',
#      'AP3D1',
#      'ARAP2',
#      'ARF6',
#      'ARGLU1',
#      'ATF4',
#      'ATM',
#      'ATP5I',
#      'ATP8A1',
#      'ATRX',
#      'BROX',
#      'C16orf54',
#      'C8orf59',
#      'CBX5',
#      'CCDC66',
#      'CMC1',
#      'COX20',
#      'CREM',
#      'DDX3X',
#      'DNMT1',
#      'FAM120A',
#      'FAM172A',
#      'FAM45A',
#      'FNBP1',
#      'GADD45G',
#      'GPBP1',
#      'GPRIN3',
#      'HEXIM1',
#      'HIST1H4C',
#      'HNRNPD',
#      'HP1BP3',
#      'KIF20B',
#      'KLF2',
#      'KMT2E',
#      'LNPEP',
#      'LRMP',
#      'LYST',
#      'MARCH6',
#      'MBNL1',
#      'MCL1',
#      'MGEA5',
#      'MT1X',
#      'MTMR9',
#      'MYCBP2',
#      'NAP1L1',
#      'NDUFA3',
#      'NR4A2',
#      'NUP50',
#      'OGT',
#      'PCM1',
#      'PFDN4',
#      'PHACTR2',
#      'PHIP',
#      'PIK3R1',
#      'PNPLA8',
#      'POMP',
#      'PPP1R10',
#      'PSD4',
#      'PTP4A2',
#      'RAB11FIP1',
#      'RASGRP1',
#      'RICTOR',
#      'RNF168',
#      'RNF19A',
#      'RNF213',
#      'RNMT',
#      'RORA',
#      'RP11-349A22.5',
#      'SAMD9',
#      'SAR1A',
#      'SEC31A',
#      'SEC62',
#      'SENP6',
#      'SETD5',
#      'SFXN1',
#      'SHFM1',
#      'SKA2',
#      'SKIL',
#      'SLA',
#      'SLC38A2',
#      'SMARCE1',
#      'SMC1A',
#      'SMEK1',
#      'SMG1',
#      'SON',
#      'SRSF5',
#      'STARD3NL',
#      'SYAP1',
#      'TATDN1',
#      'TBC1D2B',
#      'TM2D1',
#      'TNFRSF25',
#      'TRIM13',
#      'TTC19',
#      'UBA6',
#      'UHMK1',
#      'UPF2',
#      'UTRN',
#      'ZC3HAV1'],
#     'MCP3.down': ['AC009501.4',
#      'ACTB',
#      'ALDOA',
#      'ANXA1',
#      'ANXA5',
#      'ARF5',
#      'ARHGDIB',
#      'ARL2',
#      'ARPC1B',
#      'ATP5A1',
#      'ATP6V1F',
#      'ATXN8OS',
#      'B2M',
#      'C19orf43',
#      'CACYBP',
#      'CAPG',
#      'CAPZB',
#      'CCL5',
#      'CD160',
#      'CD3D',
#      'CD3E',
#      'CD52',
#      'CD7',
#      'CLIC1',
#      'CTSW',
#      'CXCR3',
#      'CYTIP',
#      'DHRS7',
#      'ECH1',
#      'EEF1A1',
#      'EMP3',
#      'ENO1',
#      'GAPDH',
#      'GNB2L1',
#      'GUK1',
#      'HLA-A',
#      'HLA-C',
#      'HLA-G',
#      'HOPX',
#      'IFITM1',
#      'IGHV1OR15-1',
#      'IL32',
#      'JUNB',
#      'LY6E',
#      'MAD2L2',
#      'MIF',
#      'MRPL24',
#      'MYL12A',
#      'MYL12B',
#      'PFN1',
#      'PLP2',
#      'PPDPF',
#      'PPP1R11',
#      'PSMB10',
#      'PSMD9',
#      'PSME2',
#      'PTGER2',
#      'RAB33A',
#      'RABAC1',
#      'RAC2',
#      'RHOC',
#      'RNA18S5',
#      'RPL10',
#      'RPL10A',
#      'RPL11',
#      'RPL12',
#      'RPL13',
#      'RPL13A',
#      'RPL14',
#      'RPL18A',
#      'RPL19',
#      'RPL3',
#      'RPL32',
#      'RPL4',
#      'RPL5',
#      'RPL6',
#      'RPL7',
#      'RPL8',
#      'RPLP0',
#      'RPS14',
#      'RPS18',
#      'RPS19',
#      'RPS2',
#      'RPS3',
#      'RPS4X',
#      'RPS5',
#      'RPS6',
#      'RPSA',
#      'SH3BGRL3',
#      'SMDT1',
#      'TECR',
#      'TMSB4X',
#      'TPI1',
#      'TRAC',
#      'TRBC2',
#      'TSR2',
#      'TUBA1A',
#      'TUBB',
#      'VAMP8',
#      'XCL1',
#      'ZFP36']},
#    'HLM_result_2':              estimate         p_val    z_score      p_adjust     up program
#    AC009501.4  -4.903615  1.814075e-82 -82.042375  1.040070e-81   True    MCP3
#    ACTB       -16.312025  7.796315e-79 -78.409141  2.052499e-78   True    MCP3
#    AKNA        51.344667  7.520159e-72  71.424803  1.276448e-71   True    MCP3
#    ALOX5AP    -13.971642  1.688701e-75 -75.073477  3.351422e-75   True    MCP3
#    ANXA1       -4.316157  3.804723e-82 -81.720707  1.963237e-81   True    MCP3
#    ...               ...           ...        ...           ...    ...     ...
#    ZFP36L2    -13.173691  2.991522e-43 -42.825138  3.508239e-43   True    MCP3
#    ZMYM2       26.546107  6.505443e-69  68.487753  9.701758e-69   True    MCP3
#    ZNF331     -12.169427  1.910677e-83 -83.019843  3.124003e-82   True    MCP3
#    CD81        32.202789  2.701971e-83  82.869349  3.485542e-82  False    MCP3
#    STK4        15.322129  4.199531e-72  71.677829  7.223194e-72  False    MCP3
#
#    [258 rows x 6 columns],
#    'sig_genes_2': {'MCP3.up': ['AKNA',
#      'ARHGAP25',
#      'ARHGAP30',
#      'ARID5B',
#      'BAZ1B',
#      'BIRC6',
#      'BRI3',
#      'BTG1',
#      'CASC4',
#      'CCDC66',
#      'CCND2',
#      'CD44',
#      'CD81',
#      'CDC42',
#      'CEBPZ',
#      'CHD2',
#      'CHD4',
#      'DDX24',
#      'DDX3X',
#      'EIF2S3',
#      'ELF1',
#      'ELMO1',
#      'EML4',
#      'EPB41',
#      'GADD45A',
#      'GCC2',
#      'GOLGA4',
#      'GRIPAP1',
#      'HSP90B1',
#      'ITM2B',
#      'KDM5A',
#      'KIAA1551',
#      'KLF2',
#      'KTN1',
#      'LYST',
#      'MIAT',
#      'MKNK2',
#      'MT-ND6',
#      'MYCBP2',
#      'NDUFS6',
#      'NIPBL',
#      'NKTR',
#      'NONO',
#      'PAK2',
#      'PCSK7',
#      'PGRMC2',
#      'PHF17',
#      'PLP2',
#      'PNN',
#      'PNRC1',
#      'POLR2A',
#      'PREX1',
#      'PRPF38B',
#      'PSMD9',
#      'PTEN',
#      'PYHIN1',
#      'RASGRP1',
#      'RBM25',
#      'RECQL',
#      'ROCK1',
#      'SETD5-AS1',
#      'SLC38A1',
#      'SMARCD1',
#      'SNHG1',
#      'SORL1',
#      'SP3',
#      'SRSF6',
#      'STK4',
#      'SYNE1',
#      'SYNRG',
#      'TAOK1',
#      'TAPBP',
#      'TCOF1',
#      'THUMPD1',
#      'TLE4',
#      'TLN1',
#      'TNRC6C',
#      'TOPORS',
#      'TRIM4',
#      'USP47',
#      'VMP1',
#      'WAC',
#      'WIPF1',
#      'WNK1',
#      'YME1L1',
#      'ZBTB38',
#      'ZBTB7A',
#      'ZEB2',
#      'ZMYM2'],
#     'MCP3.down': ['AC009501.4',
#      'ACTB',
#      'ALOX5AP',
#      'ANXA1',
#      'ARF5',
#      'ARHGDIB',
#      'ARPC1B',
#      'ARPC3',
#      'ATP5EP2',
#      'ATXN8OS',
#      'BCAS2',
#      'CAPG',
#      'CCL4',
#      'CCL5',
#      'CD160',
#      'CD3D',
#      'CD3E',
#      'CD69',
#      'CD8B',
#      'CD99',
#      'CFL1',
#      'CIB1',
#      'CLIC1',
#      'CNBP',
#      'CTSW',
#      'CXCR4',
#      'CYBA',
#      'DCTN3',
#      'DHRS7',
#      'DNAJB9',
#      'DRAP1',
#      'ECH1',
#      'EMC6',
#      'EMP3',
#      'FLT3LG',
#      'FOS',
#      'GHITM',
#      'HLA-A',
#      'HLA-C',
#      'HLA-G',
#      'HOPX',
#      'IFITM1',
#      'IL32',
#      'JUNB',
#      'LGALS1',
#      'LMAN2',
#      'LRRC69',
#      'LTB',
#      'LY6E',
#      'MIF',
#      'MYL12A',
#      'MYL12B',
#      'MYL6',
#      'NAPA',
#      'NDUFB8',
#      'OAZ1',
#      'PDCL3',
#      'PDLIM2',
#      'PFDN5',
#      'PFN1',
#      'PGK1',
#      'POLR2E',
#      'PRDX2',
#      'PRR13',
#      'PSMA5',
#      'PSMB10',
#      'PSMB6',
#      'PSMB9',
#      'PSME1',
#      'PSME2',
#      'PTGER4',
#      'RAC2',
#      'RGCC',
#      'RPL10',
#      'RPL17',
#      'RPL3',
#      'RPL6',
#      'RPL8',
#      'RPLP0',
#      'RPS18',
#      'RPS4X',
#      'RPS4Y1',
#      'S100A11',
#      'S100A4',
#      'SAMSN1',
#      'SELK',
#      'SH3BGRL3',
#      'SOCS1',
#      'SUSD3',
#      'TAGLN2',
#      'TMSB4X',
#      'TPI1',
#      'TRAPPC2P1',
#      'TSC22D3',
#      'TUBA1A',
#      'UBB',
#      'UBC',
#      'XCL1',
#      'YPEL5',
#      'ZFP36',
#      'ZNF331']}}},
#  'CD8+ IELs_vs_Macrophages': {'MCP1': {'HLM_result_1':              estimate          p_val     z_score       p_adjust    up program
#    AAK1        21.025251  8.320821e-132  131.380864  5.518018e-131  True    MCP1
#    ABCE1       26.197229  1.405749e-108  108.153122  2.663524e-108  True    MCP1
#    ABCF1       27.577923  4.958080e-129  128.605716  2.082393e-128  True    MCP1
#    AC020571.3  37.742760  2.863970e-117  116.844061  6.330882e-117  True    MCP1
#    AC092580.4   6.475982  1.833352e-120  120.037784  4.529457e-120  True    MCP1
#    ...               ...            ...         ...            ...   ...     ...
#    YWHAZ       11.977540  4.835159e-121  120.616619  1.243327e-120  True    MCP1
#    YY1         15.733985   2.296594e-59   58.939946   2.742852e-59  True    MCP1
#    ZC3HAV1     23.689698  2.137866e-120  119.971050  5.230507e-120  True    MCP1
#    ZEB2        52.988613   2.585132e-49   48.888547   2.921315e-49  True    MCP1
#    ZNF644      32.573907  1.931439e-130  130.015149  1.014006e-129  True    MCP1
#
#    [252 rows x 6 columns],
#    'sig_genes_1': {'MCP1.up': ['AAK1',
#      'ABCF1',
#      'AC092580.4',
#      'ACTR2',
#      'ANKRD36',
#      'ARAP2',
#      'ARF6',
#      'ARGLU1',
#      'ATF4',
#      'ATM',
#      'ATP8A1',
#      'BPTF',
#      'C16orf54',
#      'C8orf59',
#      'CAPZA1',
#      'CLEC2B',
#      'COX7B',
#      'COX7C',
#      'CREM',
#      'DDX3X',
#      'DNMT1',
#      'EIF3E',
#      'ELF1',
#      'ETS1',
#      'FAM45A',
#      'FNBP1',
#      'FYB',
#      'GPR65',
#      'GPRIN3',
#      'HIST1H4C',
#      'HNRNPD',
#      'HNRNPH1',
#      'HP1BP3',
#      'IFNG',
#      'IQGAP1',
#      'ITK',
#      'IWS1',
#      'KLF2',
#      'KLRB1',
#      'KLRD1',
#      'KMT2E',
#      'LNPEP',
# ...
#    SQSTM1   17.379906  1.697892e-128  128.071120  2.596777e-128  False    MCP1
#
#    [208 rows x 6 columns],
#    'sig_genes_2': {'MCP1.up': ['ADAM9',
#      'AGR2',
#      'APIP',
#      'ARF4',
#      'ARF6',
#      'ASRGL1',
#      'B3GNT7',
#      'BCLAF1',
#      'BIK',
#      'C6orf62',
#      'CALR',
#      'CCNI',
#      'CD164',
#      'CDC42',
#      'CDC42EP1',
#      'CDV3',
#      'CKAP4',
#      'CMTM6',
#      'CTNNB1',
#      'CXADR',
#      'DDX21',
#      'DDX5',
#      'DMBT1',
#      'DNAJC10',
#      'DNAJC3',
#      'EIF4G2',
#      'ETS2',
#      'FAM3C',
#      'FAM84A',
#      'G3BP1',
#      'GDF15',
#      'GLUL',
#      'GOLIM4',
#      'GPRC5A',
#      'GPX2',
#      'GSPT1',
#      'HIF1A',
#      'HIGD1A',
#      'HMGN1',
#      'HNRNPD',
#      'HNRNPH1',
#      'HOXB13',
#      'HSP90B1',
#      'KCNQ1OT1',
#      'KDELR2',
#      'KIAA1324',
#      'KIF13A',
#      'LCN2',
#      'LDHB',
#      'LEFTY1',
#      'LIPH',
#      'LMAN1',
#      'LRRFIP1',
#      'MAL2',
#      'MARCKSL1',
#      'MLPH',
#      'MORF4L1',
#      'MUC12',
#      'MUC5B',
#      'NCOA7',
#      'NEAT1',
#      'NPDC1',
#      'NUCB2',
#      'PARM1',
#      'PDIA3',
#      'PDIA6',
#      'PERP',
#      'PKN2',
#      'PLA2G2A',
#      'PPP1R12B',
#      'PTMS',
#      'PTP4A2',
#      'PYCR1',
#      'QSOX1',
#      'RCN1',
#      'RPL22L1',
#      'RPL37',
#      'RRBP1',
#      'SDCBP',
#      'SET',
#      'SFPQ',
#      'SLC40A1',
#      'SOD3',
#      'SPON1',
#      'SSR1',
#      'ST6GALNAC6',
#      'SUB1',
#      'SYNCRIP',
#      'TFF3',
#      'TM9SF3',
#      'TMED2',
#      'TMEM165',
#      'TRAM1',
#      'TRIB1',
#      'TTC3',
#      'UBE2N',
#      'WTAP',
#      'XIST',
#      'YBX3',
#      'YWHAZ',
#      'ZC3H12A'],
#     'MCP1.down': []}},
#   'MCP2': {'HLM_result_1':              estimate          p_val     z_score       p_adjust     up program
#    AC013394.2  44.831662   0.000000e+00         inf   0.000000e+00   True    MCP2
#    ACTR2       21.758310   0.000000e+00         inf   0.000000e+00   True    MCP2
#    ACTR3       23.714460   0.000000e+00         inf   0.000000e+00   True    MCP2
#    AP1S2       21.087863  2.160095e-185  184.966557  2.303645e-185   True    MCP2
#    ARPC5       19.831637   0.000000e+00         inf   0.000000e+00   True    MCP2
#    ...               ...            ...         ...            ...    ...     ...
#    VKORC1     -32.338843   0.000000e+00        -inf   0.000000e+00  False    MCP2
#    VSIG4      -19.526268   0.000000e+00        -inf   0.000000e+00  False    MCP2
#    YWHAH      -18.587319   0.000000e+00        -inf   0.000000e+00  False    MCP2
#    ZFP36      -16.386196   0.000000e+00        -inf   0.000000e+00  False    MCP2
#    ZNHIT1     -25.254383   0.000000e+00        -inf   0.000000e+00  False    MCP2
#
#    [337 rows x 6 columns],
#    'sig_genes_1': {'MCP2.up': ['AC013394.2',
#      'ACTR2',
#      'ACTR3',
#      'ARPC5',
#      'ATP5E',
#      'BCL2A1',
#      'BIRC3',
#      'C14orf2',
#      'C15orf48',
#      'C8orf59',
#      'CAB39',
#      'CAPZA1',
#      'CCNI',
#      'CD44',
#      'CD52',
#      'CDC42',
#      'CFP',
#      'CHP1',
#      'CLEC2B',
#      'CLEC7A',
#      'CMTM6',
#      'COMMD6',
#      'COX7B',
#      'COX7C',
#      'CSTA',
#      'CTD-2319I12.1',
#      'CTNNB1',
#      'CYBB',
#      'DAZAP2',
#      'DDX17',
#      'DDX3X',
#      'DTX3L',
#      'DUSP6',
#      'EEF1A1',
#      'EIF3E',
#      'EIF4B',
#      'EIF4G2',
#      'EPS15',
#      'EVI2B',
#      'FAM107B',
#      'FAM120A',
#      'FYB',
#      'GAS5',
#      'GDI2',
#      'GLIPR2',
#      'GNAQ',
#      'GPBP1',
#      'H3F3A',
#      'HINT1',
#      'HNRNPH1',
#      'IDO1',
#      'IGHG1',
#      'IGHG3',
#      'IL7R',
#      'IQGAP1',
#      'KCTD12',
#      'LCP1',
#      'LCP2',
#      'LGALS2',
#      'LIMD2',
#      'LSM5',
#      'LY96',
#      'LYN',
#      'MALAT1',
#      'MBNL1',
#      'MEF2C',
#      'MNDA',
#      'MT-ATP6',
#      'MT-ND3',
#      'MTPN',
#      'N4BP2L2',
#      'NAP1L1',
#      'NDUFB1',
#      'PAK2',
#      'PFDN4',
#      'POMP',
#      'PPA1',
#      'PPP1CB',
#      'PRKCB',
#      'PTBP3',
#      'PTEN',
#      'PTP4A2',
#      'PTPRC',
#      'PTPRE',
#      'QKI',
#      'RBPJ',
#      'RP11-1143G9.4',
#      'RPL18A',
#      'RPL21',
#      'RPL22',
#      'RPL23',
#      'RPL26',
#      'RPL27',
#      'RPL27A',
#      'RPL28',
#      'RPL34',
#      'RPL35A',
#      'RPL36',
#      'RPL37',
#      'RPL37A',
#      'RPL38',
#      'RPL39',
#      'RPL4',
#      'RPL7',
#      'RPL9',
#      'RPLP1',
#      'RPS11',
#      'RPS12',
#      'RPS13',
#      'RPS15A',
#      'RPS19',
#      'RPS20',
#      'RPS21',
#      'RPS23',
#      'RPS24',
#      'RPS25',
#      'RPS27A',
#      'RPS27L',
#      'RPS28',
#      'RPS29',
#      'RPS3A',
#      'RPS8',
#      'RSL24D1',
#      'S100A6',
#      'S100A8',
#      'SEC11A',
#      'SEC61G',
#      'SEPT7',
#      'SERPINB9',
#      'SET',
#      'SF3B14',
#      'SKP1',
#      'SNHG5',
#      'STAT1',
#      'SUB1',
#      'TMEM167A',
#      'TMSB10',
#      'TPT1',
#      'UFM1',
#      'UQCRB',
#      'WAC',
#      'WDR26',
#      'YWHAZ',
#      'ZEB2',
#      'ZFAS1'],
#     'MCP2.down': ['AC009501.4',
#      'ACP5',
#      'ADORA3',
#      'AKR1A1',
#      'AKR1B1',
#      'ANXA2',
#      'APOE',
#      'ARL2',
#      'ATP6V0B',
#      'ATP6V0D2',
#      'ATXN8OS',
#      'BANF1',
#      'BCAP31',
#      'BLVRB',
#      'BST2',
#      'C11orf31',
#      'C1QA',
#      'C1QB',
#      'C1QC',
#      'CAMK1',
#      'CCL3',
#      'CD63',
#      'CD74',
#      'CD81',
#      'CD99',
#      'CFD',
#      'CFL1',
#      'COMT',
#      'CST3',
#      'CSTB',
#      'CTSD',
#      'CYBA',
#      'DDOST',
#      'DNASE1L3',
#      'FABP3',
#      'FCER1G',
#      'FCGR2B',
#      'FCGRT',
#      'FDX1L',
#      'FOLR2',
#      'FOXP1',
#      'FTH1',
#      'FTL',
#      'FUNDC2',
#      'GUSB',
#      'HLA-C',
#      'HLA-DMA',
#      'HLA-DMB',
#      'HLA-DPA1',
#      'HLA-DPB1',
#      'HLA-DQA1',
#      'HLA-DQA2',
#      'HLA-DQB1',
#      'HLA-DQB2',
#      'HLA-DRA',
#      'HLA-DRB1',
#      'HLA-DRB5',
#      'HLA-G',
#      'HN1',
#      'HSD17B14',
#      'HSPA1A',
#      'IFI30',
#      'IGHV3-23',
#      'IGSF6',
#      'JUNB',
#      'KRTCAP2',
#      'LAPTM5',
#      'LGALS3',
#      'LGMN',
#      'LRRC69',
#      'LTC4S',
#      'MANF',
#      'MCOLN1',
#      'MIF',
#      'MRPL40',
#      'MS4A4A',
#      'MS4A6A',
#      'MT1G',
#      'MT1X',
#      'MYL6',
#      'NAGK',
#      'NCF4',
#      'NDUFA13',
#      'NGFRAP1',
#      'NME4',
#      'NUPR1',
#      'PFN1',
#      'PLA2G16',
#      'PLAUR',
#      'PLTP',
#      'PPDPF',
#      'PPIB',
#      'PRDX1',
#      'PSAP',
#      'QPRT',
#      'RAB42',
#      'RAC1',
#      'RBP1',
#      'RENBP',
#      'RGS1',
#      'RNA18S5',
#      'RNASE1',
#      'RNASET2',
#      'RNF130',
#      'RPS14',
#      'S100A11',
#      'SAT1',
#      'SCAMP2',
#      'SDS',
#      'SELK',
#      'SEPP1',
#      'SERPINF1',
#      'SLC3A2',
#      'SNORA67',
#      'SRA1',
#      'STAB1',
#      'STMN1',
#      'TBXAS1',
#      'TMEM138',
#      'TMEM147',
#      'TMEM176B',
#      'TMEM179B',
#      'TMEM208',
#      'TMEM37',
#      'TRAPPC2L',
#      'TREM2',
#      'TSPAN4',
#      'TUBA1B',
#      'UBB',
#      'UBC',
#      'UQCRC1',
#      'VKORC1',
#      'VSIG4',
#      'YWHAH',
#      'ZFP36',
#      'ZNHIT1']},
#    'HLM_result_2':           estimate          p_val     z_score       p_adjust     up program
#    ACTB     24.966338  8.137619e-100   99.390533  8.885645e-100   True    MCP2
#    ADAM9    15.243097  8.724999e-130  129.360265  2.974086e-129   True    MCP2
#    AGR2      6.670216  3.336796e-130  129.777700  1.427718e-129   True    MCP2
#    AGR3      6.266602  9.724001e-128  127.313185  2.117671e-127   True    MCP2
#    AK1      12.799526  6.211756e-100   99.507816  6.801700e-100   True    MCP2
#    ...            ...            ...         ...            ...    ...     ...
#    UQCR10  -27.940205  1.003819e-105 -105.299375  1.147222e-105  False    MCP2
#    UQCRC1  -21.886777  1.511335e-123 -123.121669  2.388884e-123  False    MCP2
#    UQCRFS1 -14.119960  3.159611e-128 -127.801396  7.285691e-128  False    MCP2
#    URAD     -4.723005  1.478581e-130 -130.131185  9.993171e-130  False    MCP2
#    ZG16    -13.658806  5.584092e-126 -125.554077  1.022880e-125  False    MCP2
#
#    [392 rows x 6 columns],
#    'sig_genes_2': {'MCP2.up': ['ADAM9',
#      'AGR2',
#      'APIP',
#      'ARF4',
#      'ARF6',
#      'ASRGL1',
#      'B3GALT5',
#      'B3GNT7',
#      'BIK',
#      'C6orf62',
#      'CALR',
#      'CANX',
#      'CCNI',
#      'CD164',
#      'CDC42',
#      'CDV3',
#      'CKAP4',
#      'CMTM6',
#      'CTNNB1',
#      'CXADR',
#      'DDX21',
#      'DDX5',
#      'DMBT1',
#      'DNAJC10',
#      'DNAJC3',
#      'EIF4G2',
#      'ETS2',
#      'FAM3C',
#      'FAM84A',
#      'GDF15',
#      'GLUL',
#      'GPRC5A',
#      'GPX2',
#      'HIF1A',
#      'HIGD1A',
#      'HMGN1',
#      'HNRNPD',
#      'HNRNPH1',
#      'HOXB13',
#      'HSP90B1',
#      'IDH2',
#      'IFITM3',
#      'KCNQ1OT1',
#      'KDELR2',
#      'LCN2',
#      'LDHB',
#      'LEFTY1',
#      'LIPH',
#      'LRRFIP1',
#      'MAL2',
#      'MARCKSL1',
#      'MIR22HG',
#      'MLPH',
#      'MORF4L1',
#      'MORF4L2',
#      'MUC12',
#      'MUC5B',
#      'NCOA7',
#      'NEAT1',
#      'NPDC1',
#      'NR4A1',
#      'NUCB2',
#      'OLFM4',
#      'PARM1',
#      'PDIA3',
#      'PDIA4',
#      'PDIA6',
#      'PERP',
#      'PIM3',
#      'PLA2G2A',
#      'PPP1R12B',
#      'PTMS',
#      'PTP4A2',
#      'QSOX1',
#      'RCN1',
#      'RPL22L1',
#      'RPL37',
#      'RRBP1',
#      'S100P',
#      'SDCBP',
#      'SET',
#      'SFPQ',
#      'SLC40A1',
#      'SLPI',
#      'SOD3',
#      'SPON1',
#      'SSR1',
#      'ST6GALNAC6',
#      'SUB1',
#      'TFF3',
#      'TM9SF3',
#      'TMED2',
#      'TMEM165',
#      'TRAM1',
#      'TRIB1',
#      'TTC3',
#      'XIST',
#      'YBX3',
#      'YWHAE',
#      'YWHAZ',
#      'ZC3H12A'],
#     'MCP2.down': ['ABR',
#      'ACAA2',
#      'ACADS',
#      'ACAT1',
#      'ADIRF',
#      'AKR1C3',
#      'AKR7A3',
#      'ALDH1A1',
#      'ALDH2',
#      'ANPEP',
#      'ATP5B',
#      'ATP5D',
#      'ATP5F1',
#      'ATP5G1',
#      'ATP5G2',
#      'ATP5G3',
#      'ATP5O',
#      'ATPIF1',
#      'ATXN8OS',
#      'BSG',
#      'C4orf48',
#      'CD99',
#      'CDHR5',
#      'CHCHD10',
#      'CKMT1A',
#      'CKMT1B',
#      'COA3',
#      'COX4I1',
#      'COX5A',
#      'COX5B',
#      'COX6A1',
#      'COX6B1',
#      'COX6C',
#      'CRYL1',
#      'CYP27A1',
#      'CYP4F12',
#      'DBI',
#      'ECH1',
#      'ECI2',
#      'EIF3K',
#      'ETHE1',
#      'FABP1',
#      'FAM162A',
#      'FAM195A',
#      'FAM213A',
#      'FCGRT',
#      'GHITM',
#      'GPX4',
#      'GSTK1',
#      'GSTM4',
#      'HADH',
#      'HSD11B2',
#      'HSPB1',
#      'ID3',
#      'LGALS3',
#      'LGALS4',
#      'MDH1',
#      'MESP1',
#      'MGST3',
#      'MPC2',
#      'MPST',
#      'MRPL34',
#      'MS4A12',
#      'MT-ND1',
#      'MT1F',
#      'MT1G',
#      'MT1H',
#      'MT1X',
#      'MT2A',
#      'NDUFA13',
#      'NDUFAB1',
#      'NDUFB9',
#      'NDUFS3',
#      'NDUFS4',
#      'NXPE4',
#      'PEBP1',
#      'PHGR1',
#      'PPARG',
#      'PRAP1',
#      'PRDX2',
#      'PRDX5',
#      'PRDX6',
#      'PTGR1',
#      'PXMP2',
#      'PYCARD',
#      'SELENBP1',
#      'SHD',
#      'SLC16A1',
#      'SLC22A18AS',
#      'SLC25A4',
#      'SLC25A5',
#      'SLC26A3',
#      'SLC39A5',
#      'SRI',
#      'SULT1A1',
#      'TMEM141',
#      'TST',
#      'UBB',
#      'UQCRFS1',
#      'URAD',
#      'ZG16']}},
#   'MCP3': {'HLM_result_1':              estimate  p_val  z_score  p_adjust     up program
#    AC009501.4  -5.804317    0.0     -inf       NaN   True    MCP3
#    ACP5       -22.995521    0.0     -inf       NaN   True    MCP3
#    ADORA3     -20.766767    0.0     -inf       NaN   True    MCP3
#    AKR1A1     -18.035514    0.0     -inf       NaN   True    MCP3
#    AKR1B1     -16.793846    0.0     -inf       NaN   True    MCP3
#    ...               ...    ...      ...       ...    ...     ...
#    VSIG4      -18.735501    0.0     -inf       NaN   True    MCP3
#    YWHAH      -17.812968    0.0     -inf       NaN   True    MCP3
#    ZFP36      -15.731773    0.0     -inf       NaN   True    MCP3
#    ZNHIT1     -24.069603    0.0     -inf       NaN   True    MCP3
#    GM2A       -27.429301    0.0     -inf       NaN  False    MCP3
#
#    [161 rows x 6 columns],
#    'sig_genes_1': {'MCP3.up': ['CD14', 'CTSC', 'TMEM176A'],
#     'MCP3.down': ['AC009501.4',
#      'ACP5',
#      'ADORA3',
#      'AKR1A1',
#      'AKR1B1',
#      'ANXA2',
#      'ARL2',
#      'ATP6V0B',
#      'ATP6V0D2',
#      'ATXN8OS',
#      'BCAP31',
#      'BST2',
#      'C11orf31',
#      'C1QA',
#      'C1QB',
#      'C1QC',
#      'CAMK1',
#      'CCL3',
#      'CD63',
#      'CD74',
#      'CD81',
#      'CD99',
#      'CFD',
#      'CFL1',
#      'COMT',
#      'CST3',
#      'CSTB',
#      'CTSD',
#      'CYBA',
#      'DDOST',
#      'DNASE1L3',
#      'FABP3',
#      'FCER1G',
#      'FCGR2B',
#      'FCGRT',
#      'FDX1L',
#      'FOLR2',
#      'FOXP1',
#      'FTH1',
#      'FTL',
#      'FUNDC2',
#      'GM2A',
#      'GPNMB',
#      'HLA-C',
#      'HLA-DMA',
#      'HLA-DMB',
#      'HLA-DPA1',
#      'HLA-DPB1',
#      'HLA-DQA1',
#      'HLA-DQA2',
#      'HLA-DQB1',
#      'HLA-DQB2',
#      'HLA-DRA',
#      'HLA-DRB1',
#      'HLA-DRB5',
#      'HLA-G',
#      'HSD17B14',
#      'HSPA1A',
#      'IFI30',
#      'IGHV3-23',
#      'IGSF6',
#      'JUNB',
#      'KRTCAP2',
#      'LAPTM5',
#      'LGALS3',
#      'LGMN',
#      'LRRC69',
#      'LTC4S',
#      'MANF',
#      'MCOLN1',
#      'MIF',
#      'MRPL40',
#      'MS4A4A',
#      'MS4A6A',
#      'MT1G',
#      'MT1X',
#      'MYL6',
#      'NAGK',
#      'NCF4',
#      'NDUFA13',
#      'NGFRAP1',
#      'NME4',
#      'NUPR1',
#      'PFN1',
#      'PLA2G16',
#      'PLAUR',
#      'PLTP',
#      'PPDPF',
#      'PPIB',
#      'PRDX1',
#      'PSAP',
#      'QPRT',
#      'RAB42',
#      'RAC1',
#      'RBP1',
#      'RGS1',
#      'RNA18S5',
#      'RNASE1',
#      'RNASET2',
#      'RNF130',
#      'S100A11',
#      'SAT1',
#      'SCAMP2',
#      'SDS',
#      'SELK',
#      'SEPP1',
#      'SERPINF1',
#      'SLC3A2',
#      'SNORA67',
#      'SRA1',
#      'STAB1',
#      'STMN1',
#      'TBXAS1',
#      'TMEM138',
#      'TMEM147',
#      'TMEM176B',
#      'TMEM179B',
#      'TMEM208',
#      'TMEM37',
#      'TREM2',
#      'TSPAN4',
#      'TUBA1B',
#      'UBB',
#      'UBC',
#      'VKORC1',
#      'VSIG4',
#      'YWHAH',
#      'ZFP36',
#      'ZNHIT1']},
#    'HLM_result_2':              estimate          p_val     z_score       p_adjust    up program
#    ABR        -41.836438  5.933768e-123 -122.527699  1.443151e-122  True    MCP3
#    AC009501.4  -6.694759  1.003863e-115 -115.299356  1.582088e-115  True    MCP3
#    ACAA2      -14.724841  2.067549e-119 -118.985574  3.888819e-119  True    MCP3
#    ACADS       -9.538936  1.452505e-125 -125.138912  5.961321e-125  True    MCP3
#    ACAT1      -14.437644  1.277703e-125 -125.194600  5.593498e-125  True    MCP3
#    ...               ...            ...         ...            ...   ...     ...
#    UQCR10     -26.651164  1.213501e-101 -101.216990  1.475677e-101  True    MCP3
#    UQCRC1     -20.953114  9.705345e-120 -119.314019  1.893023e-119  True    MCP3
#    UQCRFS1    -13.510821  4.627763e-124 -123.635659  1.284041e-123  True    MCP3
#    URAD        -4.517084  3.985757e-126 -125.700519  3.522973e-125  True    MCP3
#    ZG16       -13.073106  5.355498e-122 -121.572230  1.212682e-121  True    MCP3
#
#    [197 rows x 6 columns],
#    'sig_genes_2': {'MCP3.up': [],
#     'MCP3.down': ['ABR',
#      'ACADS',
#      'ACAT1',
#      'ADIRF',
#      'AKR1C3',
#      'AKR7A3',
#      'ALDH1A1',
#      'ALDH2',
#      'ANPEP',
#      'ATP5B',
#      'ATP5D',
#      'ATP5F1',
#      'ATP5G1',
#      'ATP5G2',
#      'ATP5G3',
#      'ATP5O',
#      'ATPIF1',
#      'ATXN8OS',
#      'BSG',
#      'C4orf48',
#      'CD99',
#      'CDHR5',
#      'CHCHD10',
#      'CKMT1A',
#      'CKMT1B',
#      'COA3',
#      'COX4I1',
#      'COX5A',
#      'COX5B',
#      'COX6A1',
#      'COX6B1',
#      'COX6C',
#      'CRYL1',
#      'CYP27A1',
#      'CYP4F12',
#      'DBI',
#      'ECH1',
#      'ECI2',
#      'EIF3K',
#      'ETHE1',
#      'FABP1',
#      'FAM162A',
#      'FAM195A',
#      'FAM213A',
#      'FCGRT',
#      'GHITM',
#      'GPX4',
#      'GSTK1',
#      'GSTM4',
#      'HADH',
#      'HSD11B2',
#      'HSPB1',
#      'ID3',
#      'LGALS3',
#      'LGALS4',
#      'MDH1',
#      'MESP1',
#      'MGST3',
#      'MPC2',
#      'MPST',
#      'MRPL34',
#      'MS4A12',
#      'MT-ND1',
#      'MT1F',
#      'MT1G',
#      'MT1H',
#      'MT1X',
#      'MT2A',
#      'NDUFA13',
#      'NDUFAB1',
#      'NDUFB9',
#      'NDUFS3',
#      'NDUFS4',
#      'NXPE4',
#      'PEBP1',
#      'PHGR1',
#      'PPARG',
#      'PRAP1',
#      'PRDX2',
#      'PRDX5',
#      'PRDX6',
#      'PTGR1',
#      'PXMP2',
#      'PYCARD',
#      'SELENBP1',
#      'SHD',
#      'SLC16A1',
#      'SLC22A18AS',
#      'SLC25A4',
#      'SLC25A5',
#      'SLC26A3',
#      'SLC39A5',
#      'SRI',
#      'SULT1A1',
#      'TMEM141',
#      'TST',
#      'UBB',
#      'UQCRC1',
#      'UQCRFS1',
#      'URAD',
#      'ZG16']}}}}

# %%
all_results.keys()
# Out:
# dict_keys(['CD8+ IELs_vs_CD8+ IL17+', 'CD8+ IELs_vs_CD8+ LP', 'CD8+ IELs_vs_Macrophages', 'CD8+ IELs_vs_TA2', 'CD8+ IL17+_vs_CD8+ LP', 'CD8+ IL17+_vs_Macrophages', 'CD8+ IL17+_vs_TA2', 'CD8+ LP_vs_Macrophages', 'CD8+ LP_vs_TA2', 'Macrophages_vs_TA2'])

# %%
new_mcps['TA2'][0].shape
# Out:
# (400, 1905)

# %%
ct_subs
# Out:
# {'CD8+ IELs': AnnData object with n_obs × n_vars = 752 × 6329
#      obs: 'nCount_RNA', 'nFeature_RNA', 'cellQ', 'gender', 'location', 'clinical.status', 'cell.subtypes', 'pathology', 'origin', 'subset', 'mcp_0', 'mcp_1', 'mcp_2'
#      var: 'name'
#      uns: 'pca', 'neighbors', 'umap'
#      obsm: 'X_pca', 'X_umap'
#      varm: 'PCs'
#      obsp: 'distances', 'connectivities',
#  'CD8+ IL17+': AnnData object with n_obs × n_vars = 99 × 6329
#      obs: 'nCount_RNA', 'nFeature_RNA', 'cellQ', 'gender', 'location', 'clinical.status', 'cell.subtypes', 'pathology', 'origin', 'subset', 'mcp_0', 'mcp_1', 'mcp_2'
#      var: 'name'
#      uns: 'pca', 'neighbors', 'umap'
#      obsm: 'X_pca', 'X_umap'
#      varm: 'PCs'
#      obsp: 'distances', 'connectivities',
#  'CD8+ LP': AnnData object with n_obs × n_vars = 1166 × 6329
#      obs: 'nCount_RNA', 'nFeature_RNA', 'cellQ', 'gender', 'location', 'clinical.status', 'cell.subtypes', 'pathology', 'origin', 'subset', 'mcp_0', 'mcp_1', 'mcp_2'
#      var: 'name'
#      uns: 'pca', 'neighbors', 'umap'
#      obsm: 'X_pca', 'X_umap'
#      varm: 'PCs'
#      obsp: 'distances', 'connectivities',
#  'Macrophages': AnnData object with n_obs × n_vars = 1452 × 6329
#      obs: 'nCount_RNA', 'nFeature_RNA', 'cellQ', 'gender', 'location', 'clinical.status', 'cell.subtypes', 'pathology', 'origin', 'subset', 'mcp_0', 'mcp_1', 'mcp_2'
#      var: 'name'
#      uns: 'pca', 'neighbors', 'umap'
#      obsm: 'X_pca', 'X_umap'
#      varm: 'PCs'
#      obsp: 'distances', 'connectivities',
#  'TA2': AnnData object with n_obs × n_vars = 1905 × 6329
#      obs: 'nCount_RNA', 'nFeature_RNA', 'cellQ', 'gender', 'location', 'clinical.status', 'cell.subtypes', 'pathology', 'origin', 'subset', 'mcp_0', 'mcp_1', 'mcp_2'
#      var: 'name'
#      uns: 'pca', 'neighbors', 'umap'
#      obsm: 'X_pca', 'X_umap'
#      varm: 'PCs'
#      obsp: 'distances', 'connectivities'}

# %%
for celltype in ct_subs.keys():
    dset=ct_subs[celltype]
    dset.varm['MCPs'] =  np.matmul(dset.varm['PCs'], ws[celltype])
    print(celltype)
    sc.pl._anndata.ranking(dset, "varm","MCPs",indices = [0,1,2,], n_points=30)
# Out:
# CD8+ IELs
# CD8+ IL17+
# CD8+ LP
# Macrophages
# TA2

# %%
ct_subs['TA2'].X
# Out:
# <1905x6329 sparse matrix of type '<class 'numpy.float32'>'
# 	with 3216264 stored elements in Compressed Sparse Column format>

# %%
sc.pp.pca(adata)

# %%
sc.pl.pca_loadings(adata)

# %%
sc.pl.pca_loadings(adata[adata.obs['cell.subtypes']=="TA2"])

# %%
adata.obs['cell.subtypes']
# Out:
# index
# N7.EpiA.AAGGTGCTACGGAG       CD8+ IELs
# N7.EpiA.AAGTAACTTGCTTT       CD8+ IELs
# N7.EpiA.ACAGTTCTTCTACT       CD8+ IELs
# N7.EpiA.ACGGTCCTGTACGT       CD8+ IELs
# N7.EpiA.ATGCGCCTGATAGA       CD8+ IELs
#                                ...
# N110.LPB.TCAGCTCCAATCGGTT          TA2
# N110.LPB.TCATTTGAGATTACCC          TA2
# N110.LPB.TGCACCTAGGTCATCT          TA2
# N110.LPB.TGGGCGTGTACAGTTC          TA2
# N110.LPB.TTGGCAATCCGTAGGC          TA2
# Name: cell.subtypes, Length: 5374, dtype: object

# %%
# Out:
# {'CD8+ IELs': array([[-4.51558424, -4.61885191, -4.69080464],
#         [ 2.05459318,  1.90733226,  1.7415654 ],
#         [-5.33662925, -5.03060889, -4.7417667 ],
#         ...,
#         [ 8.80162223,  8.93224434,  8.87128811],
#         [ 9.91239999, 10.44368289, 10.81119681],
#         [ 5.85092182,  5.43490349,  4.98992706]]),
#  'CD8+ IL17+': array([[ 5.80907278e+00,  6.26860506e+00,  6.55220472e+00],
#         [ 3.45218613e+00,  2.87884510e+00,  2.26217344e+00],
#         [ 1.43273085e+00,  7.19946318e-01,  2.81116176e-02],
#         [ 5.49220872e+00,  5.08922306e+00,  4.56361093e+00],
#         [ 4.18995623e+00,  3.57236872e+00,  3.00611144e+00],
#         [ 3.69175439e+00,  3.14014471e+00,  2.65013328e+00],
#         [ 5.17914553e+00,  4.21447208e+00,  3.23132657e+00],
#         [ 3.59398707e-01,  6.62015595e-01,  9.26685251e-01],
#         [ 9.26062480e-01,  1.64471566e+00,  2.24185859e+00],
#         [-4.84960791e+00, -5.02566800e+00, -5.05827268e+00],
#         [ 6.68645961e+00,  6.44439229e+00,  6.16671568e+00],
#         [ 6.50226816e-01,  8.86370377e-01,  1.11281053e+00],
#         [-6.99263428e+00, -6.10203977e+00, -5.15104968e+00],
#         [-1.90286579e+00, -1.31271524e+00, -6.88459655e-01],
#         [-8.76596567e-01,  3.24999145e-03,  8.76548311e-01],
#         [-1.27423479e+01, -1.19371227e+01, -1.09845655e+01],
#         [ 2.45291040e+00,  3.15012684e+00,  3.76002966e+00],
#         [-1.61352997e+01, -1.54751335e+01, -1.45459369e+01],
#         [-1.76305557e+01, -1.65001545e+01, -1.51754429e+01],
#         [-6.19244298e+00, -5.10045525e+00, -4.01396786e+00],
#         [ 4.76589888e+00,  4.39811557e+00,  3.89336571e+00],
#         [ 7.80186059e+00,  6.60483067e+00,  5.32902963e+00],
#         [ 6.63558263e+00,  6.19057072e+00,  5.62653995e+00],
#         [ 4.68555075e+00,  3.82515574e+00,  2.88170765e+00],
#         [ 2.56764676e+00,  1.87463236e+00,  1.16686949e+00],
#         [ 3.97397781e+00,  2.98409523e+00,  1.98054789e+00],
#         [-2.21020005e+00, -2.50804917e+00, -2.79477502e+00],
#         [ 3.63059320e+00,  3.38256007e+00,  3.01068310e+00],
#         [ 4.87960124e+00,  4.69066725e+00,  4.47321915e+00],
#         [ 1.08493319e+00,  8.43010421e-02, -9.28791913e-01],
#         [ 2.58884884e+00,  2.82968775e+00,  3.03663646e+00],
#         [ 2.40467219e+00,  1.96683432e+00,  1.64029962e+00],
#         [-3.78482500e-01, -3.84488950e-01, -3.94646768e-01],
#         [ 1.31010029e+00,  1.23870118e+00,  1.21688198e+00],
#         [-2.91169190e+00, -2.92024106e+00, -2.77271824e+00],
#         [ 1.19449927e+00,  6.97159048e-01,  1.93836208e-01],
#         [ 9.72295173e-01,  4.25965016e-01, -9.49322509e-02],
#         [-6.23082724e-01, -1.34384830e+00, -1.97377659e+00],
#         [-1.54231707e+00, -1.57528606e+00, -1.58868719e+00],
#         [-5.20945359e+00, -5.17494708e+00, -5.05987737e+00],
#         [-4.00504350e+00, -4.26008523e+00, -4.40218768e+00],
#         [-1.47905205e+01, -1.35723673e+01, -1.21704810e+01],
#         [-9.86332148e+00, -9.33664144e+00, -8.70601396e+00],
#         [-1.33589243e+01, -1.25566494e+01, -1.16159600e+01],
#         [-1.07625706e+01, -1.11345784e+01, -1.11698842e+01],
#         [-1.03153690e+01, -9.74559235e+00, -9.02364396e+00],
#         [-6.57840460e+00, -4.89060490e+00, -3.16760339e+00],
#         [-1.03137312e+01, -9.70565301e+00, -8.96798868e+00],
#         [-1.19222269e+01, -1.21388140e+01, -1.20529091e+01],
#         [-1.12472957e+01, -1.06120556e+01, -9.80981071e+00],
#         [-1.38297672e+01, -1.32019597e+01, -1.23642850e+01],
#         [-5.15371848e+00, -4.40970789e+00, -3.52463693e+00],
#         [-2.80528856e+00, -2.37517060e+00, -1.92523848e+00],
#         [-8.90708049e+00, -8.02265182e+00, -7.05266541e+00],
#         [-1.19272084e+01, -1.13642452e+01, -1.06653872e+01],
#         [-5.84448343e+00, -5.19804272e+00, -4.47333936e+00],
#         [-9.96157562e+00, -1.00206597e+01, -9.85195619e+00],
#         [-3.24682897e+00, -2.85052635e+00, -2.37060077e+00],
#         [ 5.91491770e+00,  5.37895109e+00,  4.77004145e+00],
#         [ 8.07141378e+00,  6.55865458e+00,  4.91258138e+00],
#         [ 8.85684485e+00,  9.08392688e+00,  9.12207488e+00],
#         [ 1.05079446e+01,  1.00540107e+01,  9.43070611e+00],
#         [ 1.13166953e+01,  1.07227072e+01,  9.96617222e+00],
#         [ 8.04474162e+00,  6.77366815e+00,  5.41092355e+00],
#         [ 4.08333363e+00,  3.33564608e+00,  2.46234528e+00],
#         [ 2.77328722e+00,  1.70351171e+00,  6.07912455e-01],
#         [-1.87405295e-01, -1.18577813e+00, -2.16261329e+00],
#         [ 3.04065073e+00,  2.83187368e+00,  2.60604018e+00],
#         [ 1.76446676e+00,  1.66482031e+00,  1.50641293e+00],
#         [ 6.72377894e+00,  6.18581063e+00,  5.54389587e+00],
#         [ 4.65363002e+00,  4.16219782e+00,  3.63318456e+00],
#         [ 2.10714128e+00,  1.43149168e+00,  8.08806703e-01],
#         [ 1.00943678e+01,  9.92448381e+00,  9.59926148e+00],
#         [-4.41323380e-01, -9.22854624e-01, -1.42069994e+00],
#         [ 1.86883445e+00,  1.73340194e+00,  1.55194425e+00],
#         [ 5.67159890e-01,  1.23244931e+00,  1.80585695e+00],
#         [ 4.98002833e+00,  4.98858502e+00,  4.87778775e+00],
#         [ 6.56345246e+00,  7.07924853e+00,  7.44954380e+00],
#         [ 1.02580117e+00,  7.23144186e-01,  4.21619344e-01],
#         [ 8.15020311e+00,  8.27874001e+00,  8.25847488e+00],
#         [ 7.70376947e+00,  8.59335762e+00,  9.29027521e+00],
#         [-3.32147480e-02,  2.71787169e-02, -4.69378324e-02],
#         [-3.13379720e+00, -2.93650122e+00, -2.74200806e+00],
#         [ 9.09493234e+00,  9.05813033e+00,  8.85655803e+00],
#         [ 8.81942160e-01,  8.94737473e-01,  8.82707049e-01],
#         [ 5.69500192e+00,  5.22762475e+00,  4.65044395e+00],
#         [-6.51579918e-01, -6.25011475e-01, -5.76056031e-01],
#         [-4.30514655e+00, -4.35522176e+00, -4.35742969e+00],
#         [-2.63538075e+00, -2.15851404e+00, -1.68720496e+00],
#         [-5.81674344e+00, -5.27059502e+00, -4.65636661e+00],
#         [ 3.64862877e+00,  4.17811826e+00,  4.65816966e+00],
#         [-8.00228568e+00, -6.90008682e+00, -5.78471175e+00],
#         [ 2.31178056e+00,  2.39971749e+00,  2.37546439e+00],
#         [ 6.78180971e+00,  7.34895133e+00,  7.74661949e+00],
#         [-3.14388937e+00, -3.34774594e+00, -3.35135668e+00],
#         [ 8.54438815e+00,  8.96909011e+00,  9.32012702e+00],
#         [ 1.02701691e+01,  9.39504606e+00,  8.43969399e+00],
#         [ 4.79559531e+00,  5.12288271e+00,  5.30294267e+00],
#         [ 1.37268194e+01,  1.35285541e+01,  1.32293529e+01]]),
#  'CD8+ LP': array([[-1.99657148, -2.52126345, -2.84793791],
#         [-0.57064108,  0.73615199,  2.09410281],
#         [-5.42356643, -5.95542798, -6.33053971],
#         ...,
#         [-4.29733413, -3.45558167, -2.50543103],
#         [ 3.28292039,  3.21633601,  3.17972892],
#         [ 6.6842007 ,  6.96354214,  7.17866099]]),
#  'Macrophages': array([[ 0.25528656,  0.43608273,  0.61702765],
#         [-4.79509718, -4.93742402, -5.00987599],
#         [-2.97190465, -3.10490134, -3.19917082],
#         ...,
#         [-2.87817375, -2.47276617, -2.06743277],
#         [12.1883686 , 12.42927717, 12.49889784],
#         [ 4.86819257,  4.37162839,  3.8240351 ]]),
#  'TA2': array([[ 7.4301349 ,  6.6961299 ,  5.84296566],
#         [ 6.9147152 ,  7.25026848,  7.50978881],
#         [ 4.95768957,  5.15436929,  5.34515655],
#         ...,
#         [ 9.56287719,  9.89889362, 10.04972117],
#         [11.21594405, 10.5257824 ,  9.59446636],
#         [ 5.7094414 ,  5.18368691,  4.60880696]])}

# %%
ct_subs['TA2'].obs['nCount_RNA']
# Out:
# index
# N7.EpiA.AAACGCACAATCGC        2176.911552
# N7.EpiA.AGATATTGATCGGT        4319.159178
# N7.EpiA.AGTCTACTTCTCTA        7230.356204
# N7.EpiA.ATATACGAAGTACC        5868.425665
# N7.EpiA.ATCTGTTGTCATTC        3130.076031
#                                  ...
# N110.LPB.TCAGCTCCAATCGGTT     7460.559706
# N110.LPB.TCATTTGAGATTACCC    10668.557015
# N110.LPB.TGCACCTAGGTCATCT     7660.799949
# N110.LPB.TGGGCGTGTACAGTTC     6040.285880
# N110.LPB.TTGGCAATCCGTAGGC     6839.696918
# Name: nCount_RNA, Length: 1905, dtype: float64

# %%
vars(dl)
# Out:
# {'sample_id': 'clinical.status',
#  'celltype_key': 'cell.subtypes',
#  'n_counts_key': 'nCount_RNA',
#  'n_mcps': 3}
